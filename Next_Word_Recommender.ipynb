# %% [markdown]
# # **Importing Dataset**

# %% [markdown]
# ## **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import re
import pickle
import random
from tqdm import tqdm

# %% [markdown]
# ## **Mounting the drive**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Displaying the dataset**

# %%
df = pd.read_csv("drive/My Drive/sample_reuters_dataset.csv")
df
# Out:
#       sentence_number                                      sentence_text
# 0                   0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...
# 1                   1  They told Reuter correspondents in Asian capit...
# 2                   2  But some exporters said that while the conflic...
# 3                   3  The U . S . Has said it will impose 300 mln dl...
# 4                   4  Unofficial Japanese estimates put the impact o...
# ...               ...                                                ...
# 9995             9995  In addition , British Printing and Communicati...
# 9996             9996  Salomon said in a filing with the Securities a...
# 9997             9997  If the court decides they should be converted ...
# 9998             9998  Harcourt is asking the court to rule the compa...
# 9999             9999  An increase in Reed shares in London today was...
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## **Displaying 10 sample dialogs**

# %%
dialogs = list(df["sentence_text"])

# %%
random.sample(dialogs,10)
# Out:
# ['MONSANTO TO BUY RHONE - POULENC POLYPHENYL BUSINESS Monsanto Chemical Company , a unit of Monsanto Co & lt ; MTC . N >, is to acquire the polyphenyls business of Rhone - Poulenc Chimie , a unit of Rhone - Poulenc & lt ; RHON . PA >, Monsanto said in a statement issued from its European headquarters .',
#  'Reagan , in imposing the curbs , said they would be lifted as soon as there was evidence of a pattern that Japan was adhering to the pact .',
#  'GREAT NORTHERN NEKOOSA & lt ; GNN > 1ST QTR NET Shr 1 . 59 dlrs vs 54 cts Net 43 . 3 mln vs 13 . 9 mln Revs 566 . 7 mln vs 487 . 8 mln Avg shrs 27 . 2 mln vs 25 . 9 mln NOTE : 1986 figures restated for adoption of financial accounting standards board statement 87 " employer \' s accounting for pensions ."',
#  'Bilizerian said he was optimistic his offer will be accepted at a meeting of the board of directors Wednesday .',
#  'Pentland said it will use proceeds to fund growth and possible acquisitions .',
#  'STOREHOUSE REPORTS HIGHER PROFITS IN 1986 / 87 53 weeks to April 4 , 1987 Share - basic 22 . 2p vs 21 . 6p - fully - diluted 21 . 6p vs 19 . 9p Final dividend 6 . 3p vs 5 . 7p , making 8 . 6p vs 7 . 7p Pretax profits 129 . 2 mln stg vs 116 . 0 mln Turnover 1 , 088 . 1 mln stg vs 968 . 4 mln Profit from retail operations 133 . 3 mln stg vs 115 . 6 mln Tax 40 . 1 mln stg vs 36 . 5 mln Profit after tax 89 . 1 mln stg vs 79 . 5 mln Extraordinary items debit 0 . 7 mln stg vs debit 24 mln NOTE - full name is Storehouse Plc & lt ; STHL . L >',
#  "THOMSON GRAND PUBLIC TAKES OVER THORN EMI ' S AUDIOVISUAL DIVISION - THOMSON",
#  'The possible acquisition is subject to any applicable real estate gains and transfer taxes , the joint statement said .',
#  '" Even before he started operations , traders estimated the manager would need to buy at least up to his 75 , 000 tonnes maximum before prices moved up to or above the 1 , 600 SDR level , and yet he appears reluctant to do so ," one manufacturer said .',
#  "Senators said they will propose a temporary ban on imports of all Toshiba products due to the company ' s illegal sales of sensitive high - technology goods to the Soviet Union ."]

# %% [markdown]
# # **Creating Vocabulary**

# %% [markdown]
# ## **Text Cleaning**

# %%
dial_clean = []

for i in dialogs:
  i = re.sub("[^a-zA-Z' ]","",i)
  i = i.lower()
  dial_clean.append(i)

# %%
random.sample(dial_clean,10)
# Out:
# ['soviet    coarse grain production is estimated at    mln tonnes  vs    mln tonnes last month ',
#  'the accumulated trade surplus over the first two months of  stands at    mln dlrs against    mln dlrs the previous year ',
#  'he did not elaborate ',
#  'as previously reported  dome is seeking approval in principle for the debt restructuring plan ',
#  'the ec tariffs  which would involve renouncing obligations entered into with the world trade body gatt  would be designed to stop a diversion of exports to the ec market from that of the u  s ',
#  "harcourt ' s recapitalization will come under scrutiny of a u  s  court in orlando  fla  monday ",
#  'the previous target for  was    tonnes ',
#  "spokesman fitzwater said  we don ' t want a trade war  but the imposition of sanctions showed the united states would act when it had evidence that trade pacts were being violated ",
#  "without giving figures  the report said last month ' s rise  partly linked to efforts to catch up with production lost earlier this year through industrial action  was due mainly to a firming of domestic demand ",
#  'mead  lt  mea  expects improved earnings this year mead corp said the outlook for its major paper markets looks strong for the second quarter and augurs well for its earnings in  ']

# %% [markdown]
# ## **Creating Vocabulary and display word count**

# %%
all_words = " ".join(dial_clean).split()

word_dict = {}

for word in all_words:
  if word in word_dict:
    word_dict[word] = word_dict[word] + 1
  else:
    word_dict[word] = 1

# %%
word_dict
# Out:
# {'asian': 13,
#  'exporters': 52,
#  'fear': 8,
#  'damage': 29,
#  'from': 1369,
#  'u': 1117,
#  's': 2864,
#  'japan': 441,
#  'rift': 1,
#  'mounting': 5,
#  'trade': 549,
#  'friction': 8,
#  'between': 191,
#  'the': 12496,
#  'and': 4599,
#  'has': 974,
#  'raised': 70,
#  'fears': 13,
#  'among': 44,
#  'many': 54,
#  'of': 6671,
#  'asia': 14,
#  "'": 2094,
#  'exporting': 12,
#  'nations': 71,
#  'that': 1376,
#  'row': 3,
#  'could': 291,
#  'inflict': 1,
#  'far': 55,
#  'reaching': 7,
#  'economic': 244,
#  'businessmen': 15,
#  'officials': 190,
#  'said': 4649,
#  'they': 518,
#  'told': 237,
#  'reuter': 27,
#  'correspondents': 3,
#  'in': 5070,
#  'capitals': 3,
#  'a': 4412,
#  'move': 101,
#  'against': 270,
#  'might': 59,
#  'boost': 45,
#  'protectionist': 22,
#  'sentiment': 10,
#  'lead': 96,
#  'to': 6337,
#  'curbs': 12,
#  'on': 1643,
#  'american': 126,
#  'imports': 242,
#  'their': 230,
#  'products': 200,
#  'but': 650,
#  'some': 278,
#  'while': 164,
#  'conflict': 3,
#  'would': 926,
#  'hurt': 11,
#  'them': 58,
#  'long': 119,
#  'run': 21,
#  'short': 87,
#  'term': 120,
#  'tokyo': 75,
#  'loss': 607,
#  'be': 1165,
#  'gain': 101,
#  'it': 1970,
#  'will': 984,
#  'impose': 20,
#  'mln': 3064,
#  'dlrs': 2140,
#  'tariffs': 82,
#  'japanese': 192,
#  'electronics': 25,
#  'goods': 69,
#  'april': 477,
#  'retaliation': 20,
#  'for': 2592,
#  'alleged': 11,
#  'failure': 23,
#  'stick': 1,
#  'pact': 59,
#  'not': 838,
#  'sell': 139,
#  'semiconductors': 9,
#  'world': 166,
#  'markets': 182,
#  'at': 1311,
#  'below': 66,
#  'cost': 86,
#  'unofficial': 1,
#  'estimates': 62,
#  'put': 59,
#  'impact': 52,
#  'billion': 1112,
#  'spokesmen': 3,
#  'major': 206,
#  'firms': 57,
#  'virtually': 14,
#  'halt': 10,
#  'exports': 294,
#  'hit': 37,
#  'by': 1375,
#  'new': 474,
#  'taxes': 29,
#  'we': 258,
#  'wouldn': 6,
#  't': 115,
#  'able': 31,
#  'do': 90,
#  'business': 171,
#  'spokesman': 166,
#  'leading': 49,
#  'firm': 114,
#  'matsushita': 1,
#  'electric': 35,
#  'industrial': 120,
#  'co': 370,
#  'ltd': 273,
#  'lt': 1498,
#  'mc': 1,
#  'if': 282,
#  'remain': 55,
#  'place': 31,
#  'any': 142,
#  'length': 1,
#  'time': 145,
#  'beyond': 12,
#  'few': 42,
#  'months': 164,
#  'mean': 11,
#  'complete': 22,
#  'erosion': 2,
#  'subject': 72,
#  'tom': 4,
#  'murtha': 1,
#  'stock': 394,
#  'analyst': 60,
#  'office': 44,
#  'broker': 21,
#  'james': 33,
#  'capel': 2,
#  'taiwan': 62,
#  'are': 625,
#  'also': 442,
#  'worried': 15,
#  'aware': 7,
#  'seriousness': 3,
#  'threat': 11,
#  'because': 214,
#  'serves': 3,
#  'as': 884,
#  'warning': 5,
#  'us': 41,
#  'senior': 40,
#  'taiwanese': 4,
#  'official': 174,
#  'who': 98,
#  'asked': 74,
#  'named': 38,
#  'had': 512,
#  'surplus': 155,
#  'last': 654,
#  'year': 1212,
#  'pct': 1811,
#  'with': 1127,
#  'helped': 21,
#  'swell': 2,
#  'foreign': 253,
#  'exchange': 279,
#  'reserves': 153,
#  'largest': 79,
#  'must': 46,
#  'quickly': 18,
#  'open': 98,
#  'our': 101,
#  'remove': 9,
#  'barriers': 12,
#  'cut': 206,
#  'import': 67,
#  'allow': 40,
#  'want': 43,
#  'defuse': 2,
#  'problems': 55,
#  'possible': 72,
#  'paul': 21,
#  'sheen': 1,
#  'chairman': 145,
#  'textile': 32,
#  'safe': 3,
#  'group': 342,
#  'south': 135,
#  'korea': 49,
#  'promotion': 5,
#  'association': 53,
#  'dispute': 24,
#  'pressure': 57,
#  'whose': 21,
#  'chief': 51,
#  'similar': 36,
#  'those': 75,
#  'up': 386,
#  'malaysia': 21,
#  'officers': 17,
#  'tough': 23,
#  'hard': 37,
#  'producers': 72,
#  'third': 67,
#  'countries': 142,
#  'expand': 25,
#  'sales': 371,
#  'hong': 26,
#  'kong': 26,
#  'where': 60,
#  'newspapers': 5,
#  'have': 542,
#  'been': 396,
#  'selling': 42,
#  'manufacturers': 15,
#  'share': 516,
#  'view': 40,
#  'other': 331,
#  'such': 100,
#  'commercial': 41,
#  'advantage': 8,
#  'outweighed': 2,
#  'further': 172,
#  'block': 19,
#  'is': 1420,
#  'very': 72,
#  'lawrence': 2,
#  'mills': 17,
#  'director': 41,
#  'general': 86,
#  'federation': 20,
#  'industry': 200,
#  'whole': 20,
#  'purpose': 9,
#  'prevent': 30,
#  'one': 508,
#  'day': 132,
#  'extended': 19,
#  'sources': 161,
#  'much': 92,
#  'more': 354,
#  'serious': 13,
#  'disadvantage': 2,
#  'action': 82,
#  'restraining': 2,
#  'he': 971,
#  'was': 1127,
#  'biggest': 24,
#  'export': 152,
#  'market': 498,
#  'accounting': 24,
#  'over': 236,
#  'domestically': 5,
#  'produced': 45,
#  'australian': 56,
#  'government': 304,
#  'awaiting': 9,
#  'outcome': 12,
#  'talks': 112,
#  'interest': 252,
#  'concern': 39,
#  'minister': 122,
#  'john': 24,
#  'button': 2,
#  'canberra': 1,
#  'friday': 44,
#  'this': 642,
#  'kind': 13,
#  'deterioration': 6,
#  'relations': 13,
#  'two': 444,
#  'which': 643,
#  'trading': 141,
#  'partners': 57,
#  'ours': 2,
#  'matter': 16,
#  'australia': 55,
#  'concerns': 9,
#  'centred': 1,
#  'coal': 7,
#  'beef': 57,
#  'significant': 34,
#  'country': 103,
#  'meanwhile': 13,
#  'diplomatic': 10,
#  'manoeuvres': 1,
#  'solve': 5,
#  'stand': 14,
#  'off': 89,
#  'continue': 84,
#  'ruling': 30,
#  'liberal': 18,
#  'democratic': 17,
#  'party': 34,
#  'yesterday': 161,
#  'outlined': 12,
#  'package': 34,
#  'measures': 67,
#  'economy': 125,
#  'proposed': 106,
#  'include': 65,
#  'large': 70,
#  'supplementary': 5,
#  'budget': 117,
#  'record': 188,
#  'public': 84,
#  'works': 12,
#  'spending': 54,
#  'first': 447,
#  'half': 113,
#  'financial': 148,
#  'call': 28,
#  'stepped': 2,
#  'an': 844,
#  'emergency': 10,
#  'measure': 16,
#  'stimulate': 27,
#  'despite': 71,
#  'prime': 73,
#  'yasuhiro': 12,
#  'nakasone': 24,
#  'avowed': 1,
#  'fiscal': 90,
#  'reform': 31,
#  'program': 66,
#  'deputy': 16,
#  'representative': 19,
#  'michael': 12,
#  'smith': 12,
#  'makoto': 3,
#  'kuroda': 9,
#  'international': 221,
#  'miti': 17,
#  'due': 160,
#  'meet': 63,
#  'washington': 92,
#  'week': 334,
#  'effort': 31,
#  'end': 275,
#  'china': 106,
#  'daily': 65,
#  'says': 143,
#  'vermin': 2,
#  'eat': 2,
#  'grain': 130,
#  'stocks': 177,
#  'survey': 8,
#  'provinces': 6,
#  'seven': 147,
#  'cities': 4,
#  'showed': 48,
#  'consume': 3,
#  'each': 119,
#  'tonnes': 535,
#  'or': 553,
#  'fruit': 3,
#  'output': 107,
#  'left': 28,
#  'rot': 3,
#  'its': 1372,
#  'vegetables': 4,
#  'paper': 27,
#  'blamed': 7,
#  'waste': 14,
#  'inadequate': 10,
#  'storage': 18,
#  'bad': 6,
#  'preservation': 2,
#  'methods': 6,
#  'launched': 20,
#  'national': 197,
#  'programme': 13,
#  'reduce': 77,
#  'calling': 10,
#  'improved': 41,
#  'technology': 40,
#  'greater': 23,
#  'production': 289,
#  'additives': 2,
#  'gave': 44,
#  'no': 277,
#  'details': 57,
#  'revise': 8,
#  'energy': 93,
#  'demand': 177,
#  'downwards': 4,
#  'ministry': 108,
#  'supply': 158,
#  'outlook': 28,
#  'august': 39,
#  'forecast': 96,
#  'downtrend': 2,
#  'expected': 274,
#  'lower': 152,
#  'projection': 6,
#  'primary': 26,
#  'supplies': 60,
#  'kilolitres': 1,
#  'kl': 2,
#  'decision': 70,
#  'follows': 45,
#  'emergence': 1,
#  'structural': 8,
#  'changes': 43,
#  'following': 75,
#  'rise': 240,
#  'value': 106,
#  'yen': 193,
#  'decline': 74,
#  'domestic': 164,
#  'power': 30,
#  'planning': 24,
#  'work': 40,
#  'out': 148,
#  'revised': 45,
#  'through': 120,
#  'deliberations': 1,
#  'committee': 74,
#  'meetings': 29,
#  'agency': 38,
#  'natural': 50,
#  'resources': 43,
#  'review': 36,
#  'breakdown': 8,
#  'including': 101,
#  'oil': 586,
#  'nuclear': 2,
#  'gas': 158,
#  'provided': 25,
#  'bulk': 17,
#  'ended': 144,
#  'march': 315,
#  'supplying': 5,
#  'estimated': 105,
#  'kilowatt': 1,
#  'hour': 10,
#  'basis': 70,
#  'followed': 23,
#  'liquefied': 3,
#  'noted': 61,
#  'thai': 15,
#  'deficit': 213,
#  'widens': 3,
#  'quarter': 377,
#  'thailand': 27,
#  'widened': 6,
#  'baht': 3,
#  'ago': 129,
#  'economics': 9,
#  'department': 183,
#  'janunary': 1,
#  'rose': 227,
#  'climate': 4,
#  'resulted': 20,
#  'increase': 221,
#  'raw': 20,
#  'materials': 45,
#  'semi': 12,
#  'finished': 8,
#  'bill': 70,
#  'however': 137,
#  'fell': 126,
#  'prices': 387,
#  'expanded': 7,
#  'growth': 258,
#  'smaller': 17,
#  'than': 366,
#  'earnings': 177,
#  'key': 51,
#  'commodities': 30,
#  'rice': 72,
#  'declined': 61,
#  'maize': 41,
#  'sugar': 130,
#  'tin': 51,
#  'canned': 4,
#  'pineapples': 1,
#  'registering': 3,
#  'high': 150,
#  'were': 597,
#  'jewellery': 1,
#  'clothing': 4,
#  'rubber': 36,
#  'indonesia': 46,
#  'sees': 76,
#  'cpo': 5,
#  'price': 397,
#  'rising': 73,
#  'sharply': 46,
#  'expects': 98,
#  'crude': 160,
#  'palm': 32,
#  'tonne': 75,
#  'fob': 14,
#  'sometime': 3,
#  'better': 41,
#  'european': 121,
#  'fall': 111,
#  'malaysian': 11,
#  'hasrul': 1,
#  'harahap': 3,
#  'junior': 4,
#  'tree': 2,
#  'crops': 33,
#  'indonesian': 10,
#  'reporters': 47,
#  'sumatran': 1,
#  'now': 173,
#  'around': 164,
#  'cif': 7,
#  'delivery': 58,
#  'rotterdam': 13,
#  'traders': 133,
#  'maintain': 37,
#  'making': 73,
#  'recent': 102,
#  'purchases': 33,
#  'so': 103,
#  'possibly': 19,
#  'second': 82,
#  'producer': 59,
#  'after': 367,
#  'forced': 16,
#  'ensure': 9,
#  'during': 110,
#  'moslem': 1,
#  'fasting': 2,
#  'month': 250,
#  'ramadan': 2,
#  'cover': 28,
#  'temporary': 24,
#  'shortage': 20,
#  'lose': 7,
#  'calendar': 18,
#  'according': 54,
#  'central': 193,
#  'bank': 616,
#  'figures': 118,
#  'ship': 16,
#  'ban': 21,
#  'ends': 15,
#  'nsw': 10,
#  'ports': 18,
#  'tug': 5,
#  'crews': 3,
#  'wales': 5,
#  'victoria': 3,
#  'western': 68,
#  'lifted': 15,
#  'flag': 9,
#  'ships': 36,
#  'carrying': 12,
#  'containers': 2,
#  'still': 112,
#  'being': 97,
#  'disrupted': 7,
#  'separate': 19,
#  'shipping': 25,
#  'imposed': 26,
#  'pay': 151,
#  'claim': 8,
#  'prevented': 7,
#  'movement': 20,
#  'port': 50,
#  'nearly': 34,
#  'vessels': 20,
#  'went': 25,
#  'before': 141,
#  'hearing': 14,
#  'arbitration': 3,
#  'commission': 111,
#  'today': 275,
#  'disruption': 3,
#  'began': 46,
#  'cargo': 20,
#  'handling': 8,
#  'sydney': 5,
#  'newcastle': 3,
#  'kembla': 3,
#  'part': 96,
#  'called': 62,
#  'trades': 14,
#  'labour': 15,
#  'council': 58,
#  'protest': 9,
#  'state': 112,
#  'workers': 54,
#  'compensation': 12,
#  'laws': 14,
#  'various': 19,
#  'unions': 11,
#  'appear': 16,
#  'taking': 38,
#  'turn': 12,
#  'start': 100,
#  'shift': 10,
#  'then': 42,
#  'walk': 1,
#  'container': 4,
#  'movements': 9,
#  'most': 108,
#  'affected': 39,
#  'stopped': 9,
#  'altogether': 4,
#  'say': 97,
#  'how': 41,
#  'go': 43,
#  'what': 77,
#  'effect': 45,
#  'commodity': 49,
#  'may': 540,
#  'likely': 106,
#  'least': 45,
#  'paian': 1,
#  'nainggolan': 3,
#  'reuters': 92,
#  'telephone': 24,
#  'interview': 22,
#  'sawn': 1,
#  'timber': 5,
#  'pepper': 1,
#  'tobacco': 19,
#  'considered': 21,
#  'either': 22,
#  'refined': 23,
#  'introduced': 23,
#  'question': 19,
#  'rachmat': 1,
#  'saleh': 2,
#  'when': 169,
#  'ahead': 28,
#  'made': 174,
#  'fledgling': 1,
#  'currently': 57,
#  'coffee': 71,
#  'physicals': 3,
#  'outcry': 1,
#  'system': 102,
#  'four': 168,
#  'days': 128,
#  'several': 82,
#  'factors': 31,
#  'make': 91,
#  'cautiously': 2,
#  'slowly': 7,
#  'safely': 1,
#  'mistake': 2,
#  'undermine': 5,
#  'confidence': 21,
#  'physical': 9,
#  'added': 219,
#  'january': 106,
#  'contracts': 42,
#  'traded': 27,
#  'five': 245,
#  'forward': 29,
#  'robusta': 2,
#  'grades': 16,
#  'prompt': 2,
#  'board': 184,
#  'considering': 32,
#  'introduction': 10,
#  'futures': 64,
#  'later': 55,
#  'feasibility': 3,
#  'study': 28,
#  'needed': 50,
#  'decisions': 13,
#  'until': 62,
#  'elections': 6,
#  'monday': 25,
#  'should': 146,
#  'marketing': 72,
#  'hoped': 14,
#  'development': 89,
#  'help': 80,
#  'trying': 26,
#  'overseas': 25,
#  'building': 42,
#  'contacts': 5,
#  'users': 7,
#  'teams': 1,
#  'already': 82,
#  'encourage': 17,
#  'direct': 15,
#  'use': 119,
#  'delegation': 9,
#  'visit': 17,
#  'europe': 45,
#  'mexico': 22,
#  'latin': 4,
#  'states': 145,
#  'participation': 7,
#  'infant': 1,
#  'good': 71,
#  'although': 66,
#  'disappointing': 4,
#  'transactions': 24,
#  'december': 89,
#  'totalled': 26,
#  'worth': 51,
#  'plus': 32,
#  'rupiah': 3,
#  'delivered': 9,
#  'locally': 2,
#  'latest': 66,
#  'report': 209,
#  'amounted': 6,
#  'only': 175,
#  'lots': 4,
#  'valued': 15,
#  'total': 293,
#  'membership': 8,
#  'nine': 111,
#  'brokers': 25,
#  'sri': 14,
#  'lanka': 13,
#  'gets': 11,
#  'usda': 108,
#  'approval': 65,
#  'wheat': 189,
#  'food': 52,
#  'agriculture': 130,
#  'approved': 64,
#  'continental': 25,
#  'sale': 147,
#  'soft': 23,
#  'c': 76,
#  'f': 52,
#  'pacific': 39,
#  'northwest': 10,
#  'colombo': 6,
#  'shipment': 32,
#  'mining': 40,
#  'gold': 99,
#  'mine': 50,
#  'corp': 623,
#  'holdings': 56,
#  'wmng': 2,
#  'wmc': 6,
#  'establish': 5,
#  'joint': 55,
#  'venture': 46,
#  'northern': 19,
#  'territory': 2,
#  'about': 515,
#  'known': 23,
#  'goodall': 1,
#  'project': 14,
#  'owned': 125,
#  'local': 53,
#  'w': 17,
#  'r': 17,
#  'grace': 11,
#  'gra': 3,
#  'unit': 171,
#  'located': 15,
#  'kms': 2,
#  'east': 52,
#  'adelaide': 1,
#  'river': 23,
#  'mt': 11,
#  'bundey': 1,
#  'statement': 168,
#  'pit': 2,
#  'conventional': 3,
#  'leach': 1,
#  'treatment': 9,
#  'plant': 66,
#  'produce': 28,
#  'ounces': 17,
#  'mid': 26,
#  'annual': 101,
#  'ore': 24,
#  'capacity': 42,
#  'sumitomo': 16,
#  'aims': 6,
#  'quick': 7,
#  'recovery': 25,
#  'merger': 128,
#  'sumi': 1,
#  'certain': 63,
#  'status': 15,
#  'profitable': 21,
#  'result': 86,
#  'heiwa': 4,
#  'sogo': 4,
#  'analysts': 185,
#  'osaka': 2,
#  'based': 142,
#  'desposits': 1,
#  'trillion': 4,
#  'merged': 6,
#  'small': 40,
#  'struggling': 3,
#  'unrecoverable': 1,
#  'loans': 118,
#  'october': 53,
#  'link': 14,
#  'president': 137,
#  'koh': 1,
#  'komatsu': 9,
#  'confident': 9,
#  'his': 105,
#  'can': 116,
#  'regain': 1,
#  'position': 67,
#  'll': 4,
#  'back': 50,
#  'within': 63,
#  'three': 277,
#  'years': 159,
#  'initially': 8,
#  'profitability': 5,
#  'efficiency': 8,
#  'vastly': 1,
#  'branch': 10,
#  'network': 18,
#  'metropolitan': 4,
#  'area': 61,
#  'relatively': 16,
#  'weak': 24,
#  'divided': 9,
#  'whether': 52,
#  'gamble': 3,
#  'paid': 65,
#  'too': 53,
#  'debts': 4,
#  'others': 18,
#  'argue': 4,
#  'effective': 91,
#  'creating': 1,
#  'comparable': 10,
#  'scratch': 1,
#  'agreed': 155,
#  'aggressive': 8,
#  'entered': 32,
#  'lucrative': 4,
#  'securities': 151,
#  'geared': 2,
#  'competition': 21,
#  'questioned': 4,
#  'wisdom': 1,
#  'moves': 36,
#  've': 14,
#  'bold': 3,
#  'everything': 3,
#  'largely': 15,
#  'hands': 11,
#  'kleinwort': 5,
#  'benson': 2,
#  'simon': 3,
#  'smithson': 2,
#  'limits': 21,
#  'placed': 18,
#  'enter': 8,
#  'investment': 161,
#  'goldman': 5,
#  'sachs': 5,
#  'limited': 34,
#  'partnership': 30,
#  'federal': 145,
#  'reserve': 109,
#  'forbidden': 1,
#  'personnel': 7,
#  'tie': 4,
#  'widely': 7,
#  'looked': 5,
#  'lame': 1,
#  'duck': 1,
#  'fed': 165,
#  'stricter': 1,
#  'regulations': 12,
#  'change': 80,
#  'near': 41,
#  'future': 51,
#  'things': 7,
#  'wait': 4,
#  'st': 281,
#  'century': 13,
#  'willing': 13,
#  'patient': 4,
#  'routes': 7,
#  'into': 186,
#  'home': 43,
#  'article': 8,
#  'act': 32,
#  'version': 3,
#  'glass': 3,
#  'steagall': 1,
#  'separates': 2,
#  'banking': 54,
#  'walls': 1,
#  'crumbling': 1,
#  'hopes': 21,
#  'deregulation': 10,
#  'create': 7,
#  'opportunities': 12,
#  'need': 49,
#  'find': 22,
#  'chances': 5,
#  'cases': 12,
#  'these': 87,
#  'related': 28,
#  'trust': 56,
#  'occur': 10,
#  'focus': 16,
#  'bond': 50,
#  'dealing': 3,
#  'strengthening': 10,
#  'meiko': 1,
#  'holds': 32,
#  'optimistic': 18,
#  'entering': 8,
#  'here': 67,
#  'swiss': 40,
#  'universal': 8,
#  'subsidiary': 132,
#  'banca': 1,
#  'del': 9,
#  'gottardo': 2,
#  'finance': 112,
#  'grant': 6,
#  'licences': 12,
#  'subsidiaries': 19,
#  'banks': 149,
#  'soon': 36,
#  'parent': 26,
#  'less': 91,
#  'reluctant': 9,
#  'push': 14,
#  'don': 40,
#  'waves': 1,
#  'expect': 49,
#  'allowed': 22,
#  'like': 37,
#  'city': 38,
#  'pushing': 7,
#  'lending': 19,
#  'individuals': 8,
#  'medium': 27,
#  'businesses': 49,
#  'replace': 9,
#  'disappearing': 1,
#  'big': 15,
#  'devote': 1,
#  'lot': 16,
#  'digesting': 1,
#  'initiatives': 5,
#  'ailing': 3,
#  'strategies': 2,
#  'absorbing': 1,
#  'juggling': 1,
#  'next': 155,
#  'decade': 5,
#  'see': 58,
#  'strategy': 25,
#  'right': 33,
#  'wrong': 4,
#  'subroto': 3,
#  'supports': 6,
#  'extension': 24,
#  'mines': 25,
#  'confirmed': 22,
#  'support': 71,
#  'sixth': 10,
#  'agreement': 258,
#  'ita': 7,
#  'necessary': 24,
#  'clarify': 2,
#  'lapse': 2,
#  'ready': 15,
#  'seventh': 7,
#  'accord': 60,
#  'believe': 41,
#  'unnecessary': 2,
#  'expire': 17,
#  'june': 238,
#  'unless': 28,
#  'thirds': 5,
#  'majority': 24,
#  'members': 49,
#  'vote': 18,
#  'bundesbank': 84,
#  'allocates': 2,
#  'marks': 82,
#  'tender': 147,
#  'accepted': 23,
#  'bids': 33,
#  'repurchase': 49,
#  'fixed': 47,
#  ...}

# %% [markdown]
# ## **Displaying vocabulary in Dataframe sorted by word-count**

# %%
word_df = pd.DataFrame({"word":list(word_dict.keys()),"count":list(word_dict.values())})
word_df = word_df.sort_values(by = "count")
word_df.reset_index(inplace=True,drop=True)

# %%
word_df
# Out:
#               word  count
# 0            ulcer      1
# 1            gaons      1
# 2      securitiesd      1
# 3       unfiltered      1
# 4       preceeding      1
# ...            ...    ...
# 12575         said   4649
# 12576           in   5070
# 12577           to   6337
# 12578           of   6671
# 12579          the  12496
#
# [12580 rows x 2 columns]

# %% [markdown]
# ### **Number of words**

# %%
len(word_df)
# Out:
# 12580

# %% [markdown]
# # **Creating the N-Gram Model**

# %% [markdown]
# ## **Creating a dataframe for N-Gram model**

# %%
dataset = pd.DataFrame()
dataset["Sentence"] = dial_clean
dataset.head(5)
# Out:
#                                             Sentence
# 0  asian exporters fear damage from u  s  japan r...
# 1  they told reuter correspondents in asian capit...
# 2  but some exporters said that while the conflic...
# 3  the u  s  has said it will impose  mln dlrs of...
# 4  unofficial japanese estimates put the impact o...

# %% [markdown]
# ## **Unigram Model**

# %%
def create_unigram(sentence):
  unigram_list = []
  tokens = sentence.split()
  for i in range(len(tokens)):
    unigram_list.append(tokens[i:i+1])
  return unigram_list

# %% [markdown]
# ## **Bigram Model**

# %%
def create_bigram(sentence):
  bigram_list = []
  tokens = sentence.split()
  for i in range(len(tokens)-1):
    bigram_list.append(tokens[i:i+2])
  return bigram_list

# %% [markdown]
# ## **Trigram Model**

# %%
def create_trigram(sentence):
  trigram_list = []
  tokens = sentence.split()
  for i in range(len(tokens)-2):
    trigram_list.append(tokens[i:i+3])
  return trigram_list

# %% [markdown]
# ## **Display the models in dataframe**

# %%
dataset['Unigram'] = dataset["Sentence"].apply(create_unigram)
dataset['Bigram'] = dataset["Sentence"].apply(create_bigram)
dataset['Trigram'] = dataset["Sentence"].apply(create_trigram)
dataset
# Out:
#                                                Sentence  \
# 0     asian exporters fear damage from u  s  japan r...
# 1     they told reuter correspondents in asian capit...
# 2     but some exporters said that while the conflic...
# 3     the u  s  has said it will impose  mln dlrs of...
# 4     unofficial japanese estimates put the impact o...
# ...                                                 ...
# 9995  in addition  british printing and communicatio...
# 9996  salomon said in a filing with the securities a...
# 9997  if the court decides they should be converted ...
# 9998  harcourt is asking the court to rule the compa...
# 9999  an increase in reed shares in london today was...
#
#                                                 Unigram  \
# 0     [[asian], [exporters], [fear], [damage], [from...
# 1     [[they], [told], [reuter], [correspondents], [...
# 2     [[but], [some], [exporters], [said], [that], [...
# 3     [[the], [u], [s], [has], [said], [it], [will],...
# 4     [[unofficial], [japanese], [estimates], [put],...
# ...                                                 ...
# 9995  [[in], [addition], [british], [printing], [and...
# 9996  [[salomon], [said], [in], [a], [filing], [with...
# 9997  [[if], [the], [court], [decides], [they], [sho...
# 9998  [[harcourt], [is], [asking], [the], [court], [...
# 9999  [[an], [increase], [in], [reed], [shares], [in...
#
#                                                  Bigram  \
# 0     [[asian, exporters], [exporters, fear], [fear,...
# 1     [[they, told], [told, reuter], [reuter, corres...
# 2     [[but, some], [some, exporters], [exporters, s...
# 3     [[the, u], [u, s], [s, has], [has, said], [sai...
# 4     [[unofficial, japanese], [japanese, estimates]...
# ...                                                 ...
# 9995  [[in, addition], [addition, british], [british...
# 9996  [[salomon, said], [said, in], [in, a], [a, fil...
# 9997  [[if, the], [the, court], [court, decides], [d...
# 9998  [[harcourt, is], [is, asking], [asking, the], ...
# 9999  [[an, increase], [increase, in], [in, reed], [...
#
#                                                 Trigram
# 0     [[asian, exporters, fear], [exporters, fear, d...
# 1     [[they, told, reuter], [told, reuter, correspo...
# 2     [[but, some, exporters], [some, exporters, sai...
# 3     [[the, u, s], [u, s, has], [s, has, said], [ha...
# 4     [[unofficial, japanese, estimates], [japanese,...
# ...                                                 ...
# 9995  [[in, addition, british], [addition, british, ...
# 9996  [[salomon, said, in], [said, in, a], [in, a, f...
# 9997  [[if, the, court], [the, court, decides], [cou...
# 9998  [[harcourt, is, asking], [is, asking, the], [a...
# 9999  [[an, increase, in], [increase, in, reed], [in...
#
# [10000 rows x 4 columns]

# %% [markdown]
# # **Language modelling using Trigram Model**

# %% [markdown]
# ## **Finding occurence of a word given previous two words**

# %%
from collections import Counter,defaultdict

model = defaultdict(lambda:defaultdict(lambda:0))

for i in range(dataset.shape[0]):
  for w1,w2,w3 in dataset["Trigram"][i]:
    model[(w1,w2)][w3] += 1

# %%
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('asian',
#               'exporters'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fear': 1}),
#              ('exporters',
#               'fear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'damage': 1}),
#              ('fear',
#               'damage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'from': 1}),
#              ('damage',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1,
#                           'local': 1}),
#              ('from',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 5,
#                           'k': 1}),
#              ('u',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'japan': 6,
#                           'and': 34,
#                           'move': 1,
#                           'has': 7,
#                           'said': 4,
#                           'products': 5,
#                           'up': 2,
#                           'pressure': 3,
#                           'last': 5,
#                           'exports': 8,
#                           'japanese': 5,
#                           'trade': 44,
#                           'department': 3,
#                           'dlrs': 36,
#                           'securities': 2,
#                           'glass': 1,
#                           'commercial': 1,
#                           'officials': 30,
#                           'farm': 6,
#                           'would': 5,
#                           'to': 6,
#                           'he': 4,
#                           'agriculture': 72,
#                           'market': 7,
#                           'corn': 12,
#                           'will': 2,
#                           'feedgrain': 1,
#                           'which': 2,
#                           'limit': 1,
#                           'based': 2,
#                           'currency': 13,
#                           'sanctions': 3,
#                           'official': 3,
#                           'not': 3,
#                           'hopes': 2,
#                           'investors': 1,
#                           'dollar': 24,
#                           'unit': 3,
#                           'where': 6,
#                           'charges': 1,
#                           'decision': 1,
#                           'chip': 2,
#                           'concern': 1,
#                           'complaint': 1,
#                           'banking': 4,
#                           'treasury': 10,
#                           'petrochemical': 2,
#                           'chemical': 3,
#                           'economy': 12,
#                           'dlr': 9,
#                           'textile': 6,
#                           'investor': 1,
#                           'defense': 4,
#                           'government': 11,
#                           'no': 2,
#                           'a': 6,
#                           'parent': 1,
#                           'acquisition': 1,
#                           'tariffs': 4,
#                           'semiconductor': 3,
#                           'firms': 4,
#                           'purchase': 1,
#                           'medical': 2,
#                           'subsidiary': 6,
#                           'loan': 1,
#                           'lawmakers': 2,
#                           'dairy': 1,
#                           'interest': 8,
#                           'engineering': 1,
#                           'reserves': 1,
#                           'producers': 3,
#                           'meat': 9,
#                           'broilers': 1,
#                           'wheat': 8,
#                           'ports': 2,
#                           'prices': 1,
#                           'economic': 3,
#                           'probably': 1,
#                           'over': 2,
#                           'steel': 2,
#                           'have': 1,
#                           'senate': 5,
#                           'oil': 11,
#                           'consumption': 1,
#                           'current': 3,
#                           'imports': 2,
#                           'at': 2,
#                           'that': 1,
#                           'output': 1,
#                           'february': 4,
#                           'aegon': 1,
#                           'insurer': 1,
#                           'thus': 1,
#                           'first': 2,
#                           'funds': 2,
#                           'energy': 4,
#                           'gulf': 4,
#                           'commitment': 2,
#                           'company': 4,
#                           'buying': 1,
#                           'lead': 2,
#                           'courier': 2,
#                           'traders': 2,
#                           'congress': 3,
#                           'remained': 1,
#                           'tobacco': 1,
#                           'italy': 1,
#                           'march': 1,
#                           'retailers': 1,
#                           'soyoil': 1,
#                           'sugar': 2,
#                           'cts': 2,
#                           'outlook': 1,
#                           'ending': 2,
#                           'orange': 3,
#                           'supply': 4,
#                           'citrus': 1,
#                           'ussr': 3,
#                           'e': 1,
#                           'exporters': 2,
#                           'bankruptcy': 4,
#                           'may': 1,
#                           'depended': 1,
#                           'than': 1,
#                           'dependency': 1,
#                           'hatching': 1,
#                           'protein': 1,
#                           'weekly': 1,
#                           'soybean': 1,
#                           'x': 1,
#                           'quality': 1,
#                           'producing': 1,
#                           'spot': 1,
#                           'm': 4,
#                           'discount': 3,
#                           'bank': 4,
#                           'money': 3,
#                           'crude': 2,
#                           'relected': 1,
#                           'west': 2,
#                           'federal': 3,
#                           'commodities': 1,
#                           'markets': 1,
#                           'financial': 2,
#                           'reflected': 1,
#                           'budget': 4,
#                           'is': 3,
#                           'hurting': 1,
#                           'calls': 3,
#                           'machinery': 2,
#                           'green': 1,
#                           'roastings': 1,
#                           'european': 1,
#                           'u': 1,
#                           'bond': 1,
#                           'richards': 1,
#                           'companies': 2,
#                           'rate': 1,
#                           'monetary': 4,
#                           'industry': 3,
#                           'mln': 1,
#                           'feeder': 2,
#                           'bancorp': 5,
#                           'employees': 1,
#                           'trust': 6,
#                           'by': 2,
#                           'underwriters': 1,
#                           'revenues': 1,
#                           'it': 1,
#                           'on': 5,
#                           'sets': 1,
#                           'sprint': 1,
#                           'gas': 1,
#                           'competitors': 1,
#                           'plants': 3,
#                           'cattle': 2,
#                           'banks': 3,
#                           'inflation': 1,
#                           'east': 1,
#                           'rice': 2,
#                           'agricultural': 3,
#                           'agency': 1,
#                           'international': 1,
#                           'customs': 1,
#                           'bankrupcty': 1,
#                           'supreme': 1,
#                           'bid': 1,
#                           'believed': 1,
#                           'bill': 1,
#                           'soybeans': 5,
#                           'commerce': 4,
#                           'urges': 2,
#                           'they': 2,
#                           'rose': 3,
#                           'the': 2,
#                           'proposal': 1,
#                           'foodgrains': 1,
#                           'reprisals': 1,
#                           'goods': 3,
#                           'china': 1,
#                           'rules': 1,
#                           'support': 1,
#                           'retaliation': 1,
#                           'central': 1,
#                           'business': 1,
#                           'trading': 2,
#                           'arm': 1,
#                           'gnp': 1,
#                           'south': 2,
#                           'had': 2,
#                           'study': 1,
#                           'consumer': 3,
#                           'industrial': 1,
#                           'industries': 1,
#                           'manufacturing': 1,
#                           'district': 6,
#                           'rig': 1,
#                           'drilling': 1,
#                           'countervailing': 1,
#                           'or': 1,
#                           'zimmerman': 1,
#                           'forest': 1,
#                           'system': 1,
#                           'in': 2,
#                           'lumbermen': 1,
#                           'lumber': 1,
#                           'justice': 1,
#                           'publishing': 1,
#                           'video': 4,
#                           'allies': 2,
#                           'frigate': 3,
#                           'thrift': 3,
#                           'unprepared': 1,
#                           'participation': 1,
#                           'military': 4,
#                           'action': 1,
#                           'court': 4,
#                           'be': 1,
#                           'hart': 1,
#                           'did': 1,
#                           'firm': 2,
#                           'sectors': 1,
#                           'investment': 1,
#                           'should': 1,
#                           'gold': 2,
#                           'salmonellosis': 1,
#                           'house': 7,
#                           'allegis': 1,
#                           'weighs': 1,
#                           'domestic': 1,
#                           "'": 1,
#                           'analysts': 1,
#                           'stocks': 2,
#                           'secretary': 2,
#                           'might': 1,
#                           'could': 2,
#                           'feed': 1,
#                           'flag': 3,
#                           'arms': 2,
#                           'warships': 3,
#                           'inc': 1,
#                           'holding': 1,
#                           'barley': 2,
#                           'flags': 2,
#                           'forces': 1,
#                           'wood': 1,
#                           'april': 1,
#                           'production': 1,
#                           'reserve': 3,
#                           'policy': 2,
#                           'upgraded': 1,
#                           'britain': 1,
#                           'owned': 1,
#                           'copper': 1,
#                           'warship': 1,
#                           'plan': 1,
#                           'during': 1,
#                           'beef': 4,
#                           'tenderloin': 1,
#                           'striploin': 1,
#                           'into': 1,
#                           'deficit': 2,
#                           'health': 1,
#                           'personal': 1,
#                           'league': 1,
#                           'benchmark': 1,
#                           'for': 2,
#                           'cent': 1,
#                           'superfund': 1,
#                           'was': 1,
#                           'chamber': 1,
#                           'technology': 1,
#                           'growth': 1,
#                           'farmers': 1,
#                           'canada': 1,
#                           'canadian': 1,
#                           'put': 1,
#                           'combining': 1,
#                           'housing': 1,
#                           'you': 1,
#                           'shaw': 1,
#                           'failed': 1,
#                           'groundnut': 1}),
#              ('s',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rift': 1,
#                           "'": 2,
#                           'west': 2,
#                           'trade': 1}),
#              ('japan',
#               'rift'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mounting': 1}),
#              ('rift',
#               'mounting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 1}),
#              ('mounting',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'friction': 1,
#                           'tension': 1}),
#              ('trade',
#               'friction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'between': 3,
#                           'with': 1,
#                           'diplomacy': 1,
#                           'and': 1}),
#              ('friction',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 3}),
#              ('between',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 5,
#                           'start': 1,
#                           'two': 18,
#                           'employers': 1,
#                           'united': 4,
#                           'demands': 1,
#                           'countries': 1,
#                           'ec': 1,
#                           'dollar': 1,
#                           'white': 1,
#                           'prime': 3,
#                           'report': 2,
#                           'increased': 1,
#                           'secured': 1,
#                           'pork': 1,
#                           'omani': 1,
#                           'group': 1,
#                           'purchase': 1,
#                           'federal': 1,
#                           'first': 1,
#                           'heaviest': 1,
#                           'growth': 1}),
#              ('the',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 413,
#                           'k': 17,
#                           'n': 1}),
#              ('s',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'japan': 6,
#                           'lead': 1,
#                           'atlas': 1,
#                           'new': 1,
#                           'japanese': 3,
#                           'rising': 1,
#                           'britain': 2,
#                           'europe': 2,
#                           'west': 3,
#                           'world': 1,
#                           'european': 1,
#                           'the': 2,
#                           'cain': 1,
#                           'canada': 2,
#                           'l': 1,
#                           'up': 1,
#                           'hong': 1,
#                           'u': 1,
#                           'its': 1,
#                           'w': 4,
#                           'other': 2,
#                           'malaysia': 1,
#                           'rupert': 1,
#                           'tight': 1,
#                           'on': 1,
#                           'canadian': 1,
#                           'raise': 1}),
#              ('and',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'has': 1,
#                           'might': 1,
#                           'with': 2,
#                           "'": 2,
#                           'harder': 1,
#                           'look': 1,
#                           'on': 3,
#                           'believe': 1,
#                           'became': 1,
#                           'which': 1,
#                           'meanwhile': 1,
#                           'rather': 1,
#                           'will': 2,
#                           'at': 1,
#                           'to': 2}),
#              ('japan',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'raised': 1,
#                           'been': 2,
#                           'the': 1,
#                           'little': 2,
#                           'violated': 1,
#                           'said': 3,
#                           'come': 1,
#                           'no': 3,
#                           'rejected': 1,
#                           'far': 1,
#                           'resulted': 1}),
#              ('has',
#               'raised'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fears': 1,
#                           'its': 2,
#                           'concern': 1,
#                           'the': 1,
#                           'his': 1,
#                           'prices': 1}),
#              ('raised',
#               'fears'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'among': 1}),
#              ('fears',
#               'among'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'many': 1}),
#              ('among',
#               'many'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 1}),
#              ('many',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'asia': 1,
#                           'the': 3}),
#              ('of',
#               'asia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {"'": 1}),
#              ('asia',
#               "'"): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 1}),
#              ("'",
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'exporting': 1,
#                           'loss': 1,
#                           'alleged': 3,
#                           'foreign': 20,
#                           'largest': 23,
#                           'trade': 23,
#                           'biggest': 7,
#                           'concerns': 1,
#                           'two': 4,
#                           'ruling': 6,
#                           'avowed': 1,
#                           'deputy': 1,
#                           'grain': 4,
#                           'fruit': 1,
#                           'electric': 1,
#                           'improved': 1,
#                           'oil': 12,
#                           'second': 6,
#                           'workers': 2,
#                           'elections': 1,
#                           'most': 6,
#                           'profitability': 1,
#                           'branch': 1,
#                           'large': 1,
#                           'largely': 1,
#                           'problems': 2,
#                           'version': 1,
#                           'the': 5,
#                           'sumitomo': 1,
#                           'smithson': 1,
#                           'a': 13,
#                           'tender': 5,
#                           'allocation': 1,
#                           'existing': 2,
#                           'gold': 5,
#                           'life': 3,
#                           'industrial': 4,
#                           'daily': 2,
#                           'agriculture': 1,
#                           'top': 5,
#                           'exports': 2,
#                           'current': 25,
#                           'gnp': 3,
#                           'major': 9,
#                           'national': 5,
#                           'neste': 1,
#                           'lt': 21,
#                           'shares': 8,
#                           'profits': 8,
#                           'oslo': 1,
#                           'plunge': 1,
#                           'full': 9,
#                           'moves': 3,
#                           'sole': 2,
#                           'lower': 2,
#                           'european': 2,
#                           'substantial': 2,
#                           'result': 1,
#                           'bond': 2,
#                           'promised': 1,
#                           'five': 4,
#                           'doorstep': 1,
#                           'vital': 1,
#                           'petrodollar': 1,
#                           'palm': 1,
#                           'redland': 3,
#                           'mln': 21,
#                           'close': 7,
#                           'appreciation': 2,
#                           'power': 2,
#                           'talks': 4,
#                           'headquarters': 1,
#                           'intentions': 1,
#                           'state': 11,
#                           'crude': 3,
#                           'steel': 1,
#                           'shareholders': 5,
#                           'referral': 1,
#                           'estimate': 6,
#                           'outstanding': 8,
#                           'plans': 3,
#                           'board': 15,
#                           'minority': 2,
#                           'retained': 1,
#                           'chief': 2,
#                           'hong': 1,
#                           'expressed': 1,
#                           'court': 2,
#                           'presidential': 1,
#                           'annual': 12,
#                           'central': 7,
#                           'weekly': 4,
#                           'award': 1,
#                           'la': 1,
#                           'buoyant': 1,
#                           'average': 5,
#                           'fertilizer': 1,
#                           'value': 3,
#                           'voting': 2,
#                           'inc': 2,
#                           'footwear': 1,
#                           'ldp': 2,
#                           'commissioner': 1,
#                           'interim': 2,
#                           'investment': 4,
#                           'pct': 20,
#                           'meetings': 6,
#                           'first': 17,
#                           'pulp': 1,
#                           'work': 3,
#                           'expected': 1,
#                           'combined': 1,
#                           'supervisory': 2,
#                           'new': 7,
#                           'increase': 1,
#                           'subsidy': 1,
#                           'sun': 1,
#                           'heating': 1,
#                           'sunflowerseed': 1,
#                           'digest': 3,
#                           'lloyds': 1,
#                           'initial': 1,
#                           'management': 6,
#                           'no': 5,
#                           'john': 1,
#                           'fall': 9,
#                           'heyman': 2,
#                           'conoco': 2,
#                           'chemical': 3,
#                           'stock': 27,
#                           'cocoa': 1,
#                           'harvest': 1,
#                           'number': 1,
#                           'suspension': 1,
#                           'net': 9,
#                           'trading': 3,
#                           'allowance': 1,
#                           'end': 5,
#                           'record': 4,
#                           'estimated': 4,
#                           'capacity': 2,
#                           'grains': 1,
#                           'authorized': 1,
#                           'mortgage': 3,
#                           'price': 3,
#                           'at': 2,
#                           'agrimont': 1,
#                           'agro': 1,
#                           'officers': 2,
#                           'receiving': 1,
#                           'common': 9,
#                           'u': 6,
#                           'not': 6,
#                           'edelman': 1,
#                           'ministry': 1,
#                           'failure': 6,
#                           'semiconductor': 1,
#                           'inaction': 1,
#                           'decision': 11,
#                           'share': 6,
#                           'closing': 3,
#                           'anything': 1,
#                           'been': 5,
#                           'basic': 1,
#                           'leading': 6,
#                           'spanish': 1,
#                           'seven': 3,
#                           'market': 1,
#                           'ambassador': 1,
#                           'negotiating': 2,
#                           'restrictive': 1,
#                           'question': 2,
#                           'recent': 4,
#                           'decline': 4,
#                           'pacemakers': 1,
#                           'expertise': 1,
#                           'production': 3,
#                           'earnings': 4,
#                           'third': 3,
#                           'export': 8,
#                           'southwestern': 1,
#                           'food': 3,
#                           'total': 12,
#                           'colville': 1,
#                           'proposal': 10,
#                           'interesting': 1,
#                           'something': 2,
#                           'women': 1,
#                           'apparel': 1,
#                           'heller': 3,
#                           'socialist': 1,
#                           'program': 1,
#                           'proposed': 9,
#                           'statement': 11,
#                           'outlook': 2,
#                           'aerospace': 2,
#                           'communications': 1,
#                           'townson': 1,
#                           'revenues': 2,
#                           'hard': 2,
#                           'targeted': 2,
#                           'purchase': 1,
#                           'pilots': 1,
#                           'ccc': 1,
#                           'cascade': 1,
#                           'previously': 3,
#                           'distilled': 1,
#                           'spirits': 1,
#                           'gin': 2,
#                           'hiccup': 1,
#                           'other': 4,
#                           'gas': 2,
#                           'april': 2,
#                           'financial': 8,
#                           'survival': 1,
#                           'encor': 2,
#                           'filing': 2,
#                           'federal': 2,
#                           'purse': 1,
#                           'flexibility': 1,
#                           'figure': 4,
#                           'gramm': 1,
#                           'collander': 1,
#                           'coffee': 3,
#                           'liquor': 1,
#                           'going': 4,
#                           'seasonally': 1,
#                           'plan': 6,
#                           'venalum': 1,
#                           'little': 1,
#                           'cable': 2,
#                           'lucrative': 1,
#                           'stance': 1,
#                           'car': 1,
#                           'authority': 1,
#                           'influence': 1,
#                           'ability': 4,
#                           'obstructionist': 1,
#                           'actions': 3,
#                           'economy': 8,
#                           'interest': 3,
#                           'main': 10,
#                           'wheat': 7,
#                           'ec': 2,
#                           'present': 3,
#                           'expansion': 1,
#                           'ordinary': 1,
#                           'stuck': 1,
#                           'sixth': 1,
#                           'capital': 2,
#                           'privatisation': 3,
#                           'sweeping': 1,
#                           'platinum': 1,
#                           'forecast': 6,
#                           'view': 3,
#                           'downward': 2,
#                           'resolve': 2,
#                           'steinhaeuser': 2,
#                           'supposed': 2,
#                           'meeting': 3,
#                           'latest': 13,
#                           'accord': 1,
#                           'g': 6,
#                           'movement': 1,
#                           'in': 1,
#                           'cohen': 1,
#                           'february': 1,
#                           'harvests': 1,
#                           'engine': 2,
#                           'shortfall': 2,
#                           'lows': 1,
#                           'position': 3,
#                           'bbc': 1,
#                           'hog': 2,
#                           'development': 1,
#                           'finance': 3,
#                           'budget': 5,
#                           'package': 1,
#                           'rise': 3,
#                           'departure': 2,
#                           'money': 2,
#                           'semi': 2,
#                           'employers': 1,
#                           'monetary': 2,
#                           'perceived': 1,
#                           'target': 5,
#                           'call': 1,
#                           'smelter': 2,
#                           'trail': 4,
#                           'herculaneum': 1,
#                           'purolator': 1,
#                           'prior': 1,
#                           'executive': 2,
#                           'family': 1,
#                           'tourism': 1,
#                           'oilseed': 1,
#                           'report': 4,
#                           'former': 2,
#                           'group': 2,
#                           'counselor': 1,
#                           'move': 7,
#                           'exxon': 1,
#                           'contract': 1,
#                           'chancellor': 1,
#                           'presentation': 1,
#                           'afternoon': 1,
#                           'last': 2,
#                           'direction': 1,
#                           'that': 1,
#                           'bradford': 1,
#                           'steelmaking': 1,
#                           'sales': 5,
#                           'done': 1,
#                           'given': 1,
#                           'cotton': 2,
#                           'officer': 4,
#                           'baker': 6,
#                           'policy': 4,
#                           'compensatory': 1,
#                           'heublein': 1,
#                           'balladur': 1,
#                           'operating': 3,
#                           'pipeline': 3,
#                           'cereals': 1,
#                           'traditional': 2,
#                           'occurance': 1,
#                           'sportswear': 1,
#                           'store': 1,
#                           'overall': 5,
#                           'beef': 2,
#                           'united': 1,
#                           'key': 1,
#                           'yield': 2,
#                           'session': 2,
#                           'scallop': 1,
#                           'dismal': 1,
#                           'consumers': 1,
#                           'donegan': 1,
#                           'estimates': 2,
#                           'crop': 2,
#                           'soybean': 5,
#                           'coarse': 1,
#                           'corn': 1,
#                           'billion': 6,
#                           'negative': 1,
#                           'stake': 6,
#                           'level': 2,
#                           'modest': 1,
#                           'borrowings': 1,
#                           'float': 2,
#                           'm': 3,
#                           'procedures': 1,
#                           'previous': 2,
#                           'what': 1,
#                           'happening': 2,
#                           'lost': 1,
#                           'overnight': 1,
#                           'washington': 1,
#                           'sharp': 4,
#                           'turmoil': 1,
#                           'wake': 1,
#                           'often': 1,
#                           'got': 2,
#                           'slide': 3,
#                           'difficult': 1,
#                           'reaction': 1,
#                           'jones': 1,
#                           'ridiculous': 2,
#                           'renewed': 1,
#                           'comments': 1,
#                           'ports': 1,
#                           'edible': 1,
#                           'explanation': 1,
#                           'paid': 1,
#                           'causing': 1,
#                           'customs': 2,
#                           'deficit': 4,
#                           'official': 6,
#                           'announcement': 13,
#                           'leader': 2,
#                           'registered': 1,
#                           'output': 1,
#                           'economic': 9,
#                           'deep': 1,
#                           'acquisition': 1,
#                           'obligations': 2,
#                           'president': 3,
#                           'disclosure': 1,
#                           'assets': 9,
#                           'usual': 1,
#                           'balance': 2,
#                           'data': 3,
#                           'articles': 1,
#                           'offering': 1,
#                           'external': 1,
#                           'manufacturing': 2,
#                           'restructuring': 4,
#                           'bid': 6,
#                           'debtholders': 2,
#                           'debt': 6,
#                           'offer': 7,
#                           'cost': 2,
#                           'patience': 2,
#                           'ifo': 2,
#                           'gains': 1,
#                           'spokeswoman': 1,
#                           'option': 2,
#                           'seagram': 1,
#                           'licence': 1,
#                           'holdings': 1,
#                           'reserves': 4,
#                           'selloff': 1,
#                           'fault': 1,
#                           'markets': 1,
#                           'gross': 3,
#                           'rapid': 1,
#                           'commitments': 1,
#                           'promise': 1,
#                           'exchange': 4,
#                           'kwacha': 1,
#                           'meet': 1,
#                           'support': 1,
#                           'change': 1,
#                           'corporate': 1,
#                           'government': 3,
#                           'developing': 1,
#                           'positive': 1,
#                           'general': 1,
#                           'non': 1,
#                           'subsequent': 1,
#                           'principal': 1,
#                           'stibnite': 1,
#                           'entire': 1,
#                           'and': 2,
#                           'has': 1,
#                           'is': 1,
#                           'dey': 2,
#                           'donaldson': 1,
#                           'herpolsheimer': 1,
#                           'heer': 1,
#                           'miller': 2,
#                           'catherine': 1,
#                           'plymouth': 1,
#                           'product': 2,
#                           'operations': 5,
#                           'conergic': 1,
#                           'backing': 2,
#                           'war': 1,
#                           'tanker': 2,
#                           'buitoni': 1,
#                           'consolidated': 1,
#                           'consumer': 4,
#                           'march': 1,
#                           'about': 1,
#                           'savings': 1,
#                           'son': 1,
#                           'paris': 1,
#                           'operator': 3,
#                           'performance': 2,
#                           'chances': 1,
#                           'smith': 1,
#                           'majority': 1,
#                           'losses': 1,
#                           'chairman': 2,
#                           'hostile': 1,
#                           'willa': 1,
#                           'recently': 1,
#                           'fiscal': 1,
#                           'nationwide': 1,
#                           'valuable': 1,
#                           'worth': 1,
#                           'accounting': 1,
#                           'rj': 1,
#                           'international': 3,
#                           'so': 1,
#                           'draft': 1,
#                           'office': 3,
#                           'reserve': 3,
#                           'telecommunications': 1,
#                           'extensive': 1,
#                           'prospects': 1,
#                           'potentially': 1,
#                           'exploration': 2,
#                           'acquisitions': 1,
#                           'spending': 3,
#                           'ounces': 2,
#                           'brooklyn': 1,
#                           'three': 3,
#                           'home': 1,
#                           'acquistions': 1,
#                           'credibility': 2,
#                           'judgement': 1,
#                           'itc': 2,
#                           'final': 1,
#                           'preliminary': 2,
#                           'coordinator': 1,
#                           'ongoing': 2,
#                           'plea': 1,
#                           'supreme': 1,
#                           'suppliers': 1,
#                           'chapter': 1,
#                           'business': 3,
#                           'wilson': 1,
#                           'subsidiary': 2,
#                           'compliance': 1,
#                           'petroleum': 2,
#                           'creditors': 1,
#                           'earlier': 2,
#                           'equity': 2,
#                           'eastern': 1,
#                           'stockholders': 1,
#                           'situations': 1,
#                           'activity': 1,
#                           'trades': 1,
#                           'futures': 1,
#                           'chrysler': 1,
#                           'quota': 1,
#                           'breweries': 1,
#                           'broadly': 2,
#                           'goal': 1,
#                           'ban': 1,
#                           'index': 1,
#                           'wholesale': 3,
#                           'liberal': 2,
#                           'visit': 3,
#                           'protected': 1,
#                           'agricultural': 1,
#                           'hitting': 1,
#                           'overreaction': 1,
#                           'spokesman': 2,
#                           'remarks': 2,
#                           'more': 2,
#                           'fried': 1,
#                           'legislation': 1,
#                           'one': 3,
#                           'time': 1,
#                           'continuing': 1,
#                           'bow': 1,
#                           'very': 2,
#                           'plus': 1,
#                           'assumption': 2,
#                           'clear': 1,
#                           'figures': 2,
#                           'fair': 1,
#                           'businesses': 1,
#                           'unfair': 1,
#                           'intervention': 5,
#                           'news': 2,
#                           'recommendations': 1,
#                           'cleveland': 1,
#                           'jungle': 1,
#                           'km': 1,
#                           'schlesinger': 5,
#                           'regulations': 2,
#                           'removal': 1,
#                           'swelling': 1,
#                           'competitiveness': 1,
#                           'prospecting': 1,
#                           'rate': 2,
#                           'department': 4,
#                           'population': 1,
#                           'colombo': 1,
#                           'buffer': 2,
#                           'fiduciary': 1,
#                           'special': 4,
#                           'recommendation': 2,
#                           'stated': 1,
#                           'backlog': 1,
#                           'imf': 1,
#                           'deadline': 1,
#                           'currently': 1,
#                           'renegotiation': 1,
#                           'ex': 1,
#                           'edition': 1,
#                           'wholly': 3,
#                           'newly': 1,
#                           'british': 1,
#                           'surplus': 1,
#                           'medium': 1,
#                           'return': 1,
#                           'campeau': 1,
#                           'division': 1,
#                           'senior': 1,
#                           'cabinet': 2,
#                           'plume': 1,
#                           'zimmerman': 1,
#                           'softwood': 1,
#                           'lobby': 1,
#                           'liemandt': 2,
#                           'posted': 1,
#                           'copper': 1,
#                           'fifth': 1,
#                           'projected': 1,
#                           'dockworkers': 2,
#                           'waterford': 1,
#                           'registration': 1,
#                           'defence': 1,
#                           'hurricane': 1,
#                           'johnson': 1,
#                           'restricted': 1,
#                           'cochrane': 1,
#                           'bank': 1,
#                           'launer': 1,
#                           'citizens': 1,
#                           'action': 1,
#                           'case': 1,
#                           'legal': 1,
# ...
#               'tonne'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fob': 1,
#                           'cif': 3,
#                           'c': 3,
#                           'or': 1,
#                           'this': 1,
#                           'it': 1,
#                           'effective': 2,
#                           'per': 2,
#                           'cost': 1,
#                           'from': 2,
#                           'level': 1,
#                           'to': 1,
#                           'he': 1,
#                           'announced': 1,
#                           'on': 2,
#                           'six': 1}),
#              ('tonne',
#               'fob'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sometime': 1,
#                           'previous': 2,
#                           'with': 1}),
#              ('fob',
#               'sometime'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'this': 1}),
#              ('sometime',
#               'this'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 1}),
#              ('year',
#               'because'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 6,
#                           'the': 3,
#                           'high': 1}),
#              ('because',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'better': 1,
#                           'the': 28,
#                           'health': 1,
#                           'restructuring': 1,
#                           'planned': 1,
#                           'drought': 1,
#                           'a': 10,
#                           'particularly': 1,
#                           'setbacks': 1,
#                           'an': 2,
#                           'including': 1,
#                           'non': 1,
#                           'changes': 1,
#                           'competition': 1,
#                           'more': 1,
#                           'their': 1,
#                           'production': 1,
#                           'gencorp': 1,
#                           'recent': 1,
#                           'unprecedented': 1,
#                           'our': 1,
#                           'rising': 4,
#                           'its': 5,
#                           'uncertainty': 1,
#                           'foreign': 1,
#                           'distortions': 1,
#                           'extreme': 1,
#                           'low': 2,
#                           'inadequate': 1,
#                           'flood': 1,
#                           'flooding': 1,
#                           'severe': 1,
#                           'any': 1,
#                           'greater': 1,
#                           'japan': 1,
#                           'inefficiencies': 2,
#                           'over': 2,
#                           'opposition': 1,
#                           'congressional': 1,
#                           'exchange': 1,
#                           'insufficient': 1,
#                           'several': 1}),
#              ('of',
#               'better'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'european': 1}),
#              ('better',
#               'european'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'demand': 1}),
#              ('european',
#               'demand'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 1}),
#              ('demand',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1,
#                           'in': 1,
#                           'less': 1,
#                           'welcomed': 1,
#                           'production': 2,
#                           'lead': 1,
#                           'because': 1,
#                           'will': 2,
#                           'price': 1,
#                           'low': 1,
#                           'tight': 1,
#                           'higher': 1,
#                           'tougher': 1,
#                           'increase': 1}),
#              ('a',
#               'fall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 4,
#                           'of': 5,
#                           'from': 1}),
#              ('fall',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'malaysian': 1,
#                           'the': 9,
#                           'sales': 1,
#                           'march': 1,
#                           'key': 1,
#                           'imports': 1,
#                           'oil': 3,
#                           'but': 1,
#                           'latest': 1,
#                           'week': 1,
#                           'major': 1,
#                           'note': 1,
#                           'january': 2,
#                           'exports': 1,
#                           'february': 1,
#                           'input': 1,
#                           'industrial': 2,
#                           'a': 1,
#                           'may': 3,
#                           'unemployment': 1,
#                           'canadian': 1}),
#              ('in',
#               'malaysian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'output': 1,
#                           'and': 1}),
#              ('malaysian',
#               'output'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'hasrul': 1}),
#              ('output',
#               'hasrul'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'harahap': 1}),
#              ('hasrul',
#               'harahap'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'junior': 1}),
#              ('harahap',
#               'junior'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'minister': 1}),
#              ('junior',
#               'minister'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'for': 1}),
#              ('minister',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tree': 1,
#                           'foreign': 1}),
#              ('for',
#               'tree'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'crops': 1}),
#              ('tree',
#               'crops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'told': 1}),
#              ('crops',
#               'told'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'indonesian': 1}),
#              ('told',
#               'indonesian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'reporters': 1}),
#              ('prices',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'malaysian': 1,
#                           'pct': 1,
#                           'grain': 1,
#                           'corn': 1,
#                           'home': 1,
#                           'cement': 1,
#                           'the': 1,
#                           'petrol': 4,
#                           'cents': 1,
#                           'gm': 1,
#                           'coconut': 1,
#                           'its': 1,
#                           'aluminum': 4,
#                           'up': 1,
#                           'such': 1,
#                           'to': 1,
#                           'tungsten': 1,
#                           'high': 1,
#                           'sweet': 1,
#                           'around': 1}),
#              ('of',
#               'malaysian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 1,
#                           'refined': 1}),
#              ('malaysian',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sumatran': 1,
#                           'japanese': 1,
#                           'indonesian': 1}),
#              ('and',
#               'sumatran'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cpo': 1}),
#              ('sumatran',
#               'cpo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'are': 1}),
#              ('cpo',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'now': 1}),
#              ('are',
#               'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'around': 1,
#                           'within': 2,
#                           'near': 1,
#                           'paying': 1,
#                           'being': 1}),
#              ('now',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dlrs': 1}),
#              ('around',
#               'dlrs'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 13,
#                           'per': 1}),
#              ('tonne',
#               'cif'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'for': 1}),
#              ('cif',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'delivery': 1}),
#              ('for',
#               'delivery'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 9,
#                           'between': 1,
#                           'to': 3,
#                           'may': 3,
#                           'during': 5,
#                           'as': 1,
#                           'at': 1,
#                           'august': 1,
#                           'before': 1,
#                           'of': 1}),
#              ('delivery',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rotterdam': 1,
#                           'the': 5,
#                           'including': 1,
#                           'gold': 1,
#                           'two': 1,
#                           'late': 1}),
#              ('in',
#               'rotterdam'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'traders': 1,
#                           'the': 1}),
#              ('rotterdam',
#               'traders'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1}),
#              ('harahap',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'indonesia': 1,
#                           'it': 1}),
#              ('said',
#               'indonesia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'would': 1,
#                           'was': 1,
#                           "'": 2,
#                           'had': 1}),
#              ('indonesia',
#               'would'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'maintain': 1}),
#              ('would',
#               'maintain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'its': 1}),
#              ('maintain',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'exports': 1,
#                           'latest': 1,
#                           'dialogue': 1,
#                           'current': 2,
#                           'pct': 1}),
#              ('its',
#               'exports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'despite': 1}),
#              ('exports',
#               'despite'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'making': 1}),
#              ('despite',
#               'making'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'recent': 1}),
#              ('making',
#               'recent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'palm': 1}),
#              ('recent',
#               'palm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'oil': 1}),
#              ('oil',
#               'purchases'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'from': 1}),
#              ('purchases',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'malaysia': 1}),
#              ('from',
#               'malaysia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'so': 1}),
#              ('malaysia',
#               'so'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'that': 1}),
#              ('so',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'it': 1,
#                           'we': 2,
#                           'certain': 1,
#                           'more': 1,
#                           'abe': 2,
#                           'in': 2}),
#              ('that',
#               'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'could': 1,
#                           "'": 2,
#                           'had': 6,
#                           'plans': 1,
#                           'has': 10,
#                           'was': 10,
#                           'is': 9,
#                           'wants': 1,
#                           'may': 2,
#                           'should': 1,
#                           'proposed': 1,
#                           'continue': 1,
#                           'did': 1,
#                           'owns': 1,
#                           'made': 2,
#                           'would': 13,
#                           'wanted': 1,
#                           'already': 1,
#                           'will': 3,
#                           'does': 2,
#                           'turned': 1,
#                           'the': 1,
#                           'and': 1,
#                           'intends': 1,
#                           'regards': 1,
#                           'announced': 1,
#                           'enjoyed': 1,
#                           'awarded': 1}),
#              ('it',
#               'could'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'possibly': 1,
#                           'open': 1,
#                           'be': 2,
#                           'put': 1,
#                           'sustain': 1,
#                           'take': 2,
#                           'realize': 1,
#                           'also': 2,
#                           'still': 1,
#                           'drop': 1,
#                           'lead': 1,
#                           'not': 1}),
#              ('could',
#               'possibly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'increase': 1}),
#              ('possibly',
#               'increase'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'its': 1}),
#              ('increase',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'international': 1,
#                           'holding': 1,
#                           'annual': 1,
#                           'sales': 1,
#                           'wheat': 1,
#                           'dlr': 1,
#                           'stake': 1,
#                           'provision': 1,
#                           'ability': 1}),
#              ('its',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'market': 1,
#                           'oil': 1,
#                           'value': 1,
#                           'business': 1}),
#              ('international',
#               'market'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'share': 1,
#                           'because': 1}),
#              ('indonesia',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'world': 1}),
#              ('s',
#               'second'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'largest': 4,
#                           'hand': 1,
#                           'quarter': 1}),
#              ('second',
#               'largest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'producer': 2,
#                           'employer': 2,
#                           'gold': 1,
#                           'consumers': 1}),
#              ('largest',
#               'producer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 2,
#                           'in': 1}),
#              ...})

# %% [markdown]
# ## **Examples**

# %%
dict(model['has','raised'])
# Out:
# {'fears': 1, 'its': 2, 'concern': 1, 'the': 1, 'his': 1, 'prices': 1}

# %%
dict(model['japan','has'])
# Out:
# {'raised': 1,
#  'been': 2,
#  'the': 1,
#  'little': 2,
#  'violated': 1,
#  'said': 3,
#  'come': 1,
#  'no': 3,
#  'rejected': 1,
#  'far': 1,
#  'resulted': 1}

# %% [markdown]
# ## **Find probability of occurence of a word**

# %%
unigram_dict = {}

for i in tqdm(range(dataset.shape[0])):
  for word in dataset["Unigram"][i]:
    if word[0] in unigram_dict:
      unigram_dict[word[0]] += 1
    else:
      unigram_dict[word[0]] = 1
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 37998.18it/s]

# %%
unigram_dict
# Out:
# {'asian': 13,
#  'exporters': 52,
#  'fear': 8,
#  'damage': 29,
#  'from': 1369,
#  'u': 1117,
#  's': 2864,
#  'japan': 441,
#  'rift': 1,
#  'mounting': 5,
#  'trade': 549,
#  'friction': 8,
#  'between': 191,
#  'the': 12496,
#  'and': 4599,
#  'has': 974,
#  'raised': 70,
#  'fears': 13,
#  'among': 44,
#  'many': 54,
#  'of': 6671,
#  'asia': 14,
#  "'": 2094,
#  'exporting': 12,
#  'nations': 71,
#  'that': 1376,
#  'row': 3,
#  'could': 291,
#  'inflict': 1,
#  'far': 55,
#  'reaching': 7,
#  'economic': 244,
#  'businessmen': 15,
#  'officials': 190,
#  'said': 4649,
#  'they': 518,
#  'told': 237,
#  'reuter': 27,
#  'correspondents': 3,
#  'in': 5070,
#  'capitals': 3,
#  'a': 4412,
#  'move': 101,
#  'against': 270,
#  'might': 59,
#  'boost': 45,
#  'protectionist': 22,
#  'sentiment': 10,
#  'lead': 96,
#  'to': 6337,
#  'curbs': 12,
#  'on': 1643,
#  'american': 126,
#  'imports': 242,
#  'their': 230,
#  'products': 200,
#  'but': 650,
#  'some': 278,
#  'while': 164,
#  'conflict': 3,
#  'would': 926,
#  'hurt': 11,
#  'them': 58,
#  'long': 119,
#  'run': 21,
#  'short': 87,
#  'term': 120,
#  'tokyo': 75,
#  'loss': 607,
#  'be': 1165,
#  'gain': 101,
#  'it': 1970,
#  'will': 984,
#  'impose': 20,
#  'mln': 3064,
#  'dlrs': 2140,
#  'tariffs': 82,
#  'japanese': 192,
#  'electronics': 25,
#  'goods': 69,
#  'april': 477,
#  'retaliation': 20,
#  'for': 2592,
#  'alleged': 11,
#  'failure': 23,
#  'stick': 1,
#  'pact': 59,
#  'not': 838,
#  'sell': 139,
#  'semiconductors': 9,
#  'world': 166,
#  'markets': 182,
#  'at': 1311,
#  'below': 66,
#  'cost': 86,
#  'unofficial': 1,
#  'estimates': 62,
#  'put': 59,
#  'impact': 52,
#  'billion': 1112,
#  'spokesmen': 3,
#  'major': 206,
#  'firms': 57,
#  'virtually': 14,
#  'halt': 10,
#  'exports': 294,
#  'hit': 37,
#  'by': 1375,
#  'new': 474,
#  'taxes': 29,
#  'we': 258,
#  'wouldn': 6,
#  't': 115,
#  'able': 31,
#  'do': 90,
#  'business': 171,
#  'spokesman': 166,
#  'leading': 49,
#  'firm': 114,
#  'matsushita': 1,
#  'electric': 35,
#  'industrial': 120,
#  'co': 370,
#  'ltd': 273,
#  'lt': 1498,
#  'mc': 1,
#  'if': 282,
#  'remain': 55,
#  'place': 31,
#  'any': 142,
#  'length': 1,
#  'time': 145,
#  'beyond': 12,
#  'few': 42,
#  'months': 164,
#  'mean': 11,
#  'complete': 22,
#  'erosion': 2,
#  'subject': 72,
#  'tom': 4,
#  'murtha': 1,
#  'stock': 394,
#  'analyst': 60,
#  'office': 44,
#  'broker': 21,
#  'james': 33,
#  'capel': 2,
#  'taiwan': 62,
#  'are': 625,
#  'also': 442,
#  'worried': 15,
#  'aware': 7,
#  'seriousness': 3,
#  'threat': 11,
#  'because': 214,
#  'serves': 3,
#  'as': 884,
#  'warning': 5,
#  'us': 41,
#  'senior': 40,
#  'taiwanese': 4,
#  'official': 174,
#  'who': 98,
#  'asked': 74,
#  'named': 38,
#  'had': 512,
#  'surplus': 155,
#  'last': 654,
#  'year': 1212,
#  'pct': 1811,
#  'with': 1127,
#  'helped': 21,
#  'swell': 2,
#  'foreign': 253,
#  'exchange': 279,
#  'reserves': 153,
#  'largest': 79,
#  'must': 46,
#  'quickly': 18,
#  'open': 98,
#  'our': 101,
#  'remove': 9,
#  'barriers': 12,
#  'cut': 206,
#  'import': 67,
#  'allow': 40,
#  'want': 43,
#  'defuse': 2,
#  'problems': 55,
#  'possible': 72,
#  'paul': 21,
#  'sheen': 1,
#  'chairman': 145,
#  'textile': 32,
#  'safe': 3,
#  'group': 342,
#  'south': 135,
#  'korea': 49,
#  'promotion': 5,
#  'association': 53,
#  'dispute': 24,
#  'pressure': 57,
#  'whose': 21,
#  'chief': 51,
#  'similar': 36,
#  'those': 75,
#  'up': 386,
#  'malaysia': 21,
#  'officers': 17,
#  'tough': 23,
#  'hard': 37,
#  'producers': 72,
#  'third': 67,
#  'countries': 142,
#  'expand': 25,
#  'sales': 371,
#  'hong': 26,
#  'kong': 26,
#  'where': 60,
#  'newspapers': 5,
#  'have': 542,
#  'been': 396,
#  'selling': 42,
#  'manufacturers': 15,
#  'share': 516,
#  'view': 40,
#  'other': 331,
#  'such': 100,
#  'commercial': 41,
#  'advantage': 8,
#  'outweighed': 2,
#  'further': 172,
#  'block': 19,
#  'is': 1420,
#  'very': 72,
#  'lawrence': 2,
#  'mills': 17,
#  'director': 41,
#  'general': 86,
#  'federation': 20,
#  'industry': 200,
#  'whole': 20,
#  'purpose': 9,
#  'prevent': 30,
#  'one': 508,
#  'day': 132,
#  'extended': 19,
#  'sources': 161,
#  'much': 92,
#  'more': 354,
#  'serious': 13,
#  'disadvantage': 2,
#  'action': 82,
#  'restraining': 2,
#  'he': 971,
#  'was': 1127,
#  'biggest': 24,
#  'export': 152,
#  'market': 498,
#  'accounting': 24,
#  'over': 236,
#  'domestically': 5,
#  'produced': 45,
#  'australian': 56,
#  'government': 304,
#  'awaiting': 9,
#  'outcome': 12,
#  'talks': 112,
#  'interest': 252,
#  'concern': 39,
#  'minister': 122,
#  'john': 24,
#  'button': 2,
#  'canberra': 1,
#  'friday': 44,
#  'this': 642,
#  'kind': 13,
#  'deterioration': 6,
#  'relations': 13,
#  'two': 444,
#  'which': 643,
#  'trading': 141,
#  'partners': 57,
#  'ours': 2,
#  'matter': 16,
#  'australia': 55,
#  'concerns': 9,
#  'centred': 1,
#  'coal': 7,
#  'beef': 57,
#  'significant': 34,
#  'country': 103,
#  'meanwhile': 13,
#  'diplomatic': 10,
#  'manoeuvres': 1,
#  'solve': 5,
#  'stand': 14,
#  'off': 89,
#  'continue': 84,
#  'ruling': 30,
#  'liberal': 18,
#  'democratic': 17,
#  'party': 34,
#  'yesterday': 161,
#  'outlined': 12,
#  'package': 34,
#  'measures': 67,
#  'economy': 125,
#  'proposed': 106,
#  'include': 65,
#  'large': 70,
#  'supplementary': 5,
#  'budget': 117,
#  'record': 188,
#  'public': 84,
#  'works': 12,
#  'spending': 54,
#  'first': 447,
#  'half': 113,
#  'financial': 148,
#  'call': 28,
#  'stepped': 2,
#  'an': 844,
#  'emergency': 10,
#  'measure': 16,
#  'stimulate': 27,
#  'despite': 71,
#  'prime': 73,
#  'yasuhiro': 12,
#  'nakasone': 24,
#  'avowed': 1,
#  'fiscal': 90,
#  'reform': 31,
#  'program': 66,
#  'deputy': 16,
#  'representative': 19,
#  'michael': 12,
#  'smith': 12,
#  'makoto': 3,
#  'kuroda': 9,
#  'international': 221,
#  'miti': 17,
#  'due': 160,
#  'meet': 63,
#  'washington': 92,
#  'week': 334,
#  'effort': 31,
#  'end': 275,
#  'china': 106,
#  'daily': 65,
#  'says': 143,
#  'vermin': 2,
#  'eat': 2,
#  'grain': 130,
#  'stocks': 177,
#  'survey': 8,
#  'provinces': 6,
#  'seven': 147,
#  'cities': 4,
#  'showed': 48,
#  'consume': 3,
#  'each': 119,
#  'tonnes': 535,
#  'or': 553,
#  'fruit': 3,
#  'output': 107,
#  'left': 28,
#  'rot': 3,
#  'its': 1372,
#  'vegetables': 4,
#  'paper': 27,
#  'blamed': 7,
#  'waste': 14,
#  'inadequate': 10,
#  'storage': 18,
#  'bad': 6,
#  'preservation': 2,
#  'methods': 6,
#  'launched': 20,
#  'national': 197,
#  'programme': 13,
#  'reduce': 77,
#  'calling': 10,
#  'improved': 41,
#  'technology': 40,
#  'greater': 23,
#  'production': 289,
#  'additives': 2,
#  'gave': 44,
#  'no': 277,
#  'details': 57,
#  'revise': 8,
#  'energy': 93,
#  'demand': 177,
#  'downwards': 4,
#  'ministry': 108,
#  'supply': 158,
#  'outlook': 28,
#  'august': 39,
#  'forecast': 96,
#  'downtrend': 2,
#  'expected': 274,
#  'lower': 152,
#  'projection': 6,
#  'primary': 26,
#  'supplies': 60,
#  'kilolitres': 1,
#  'kl': 2,
#  'decision': 70,
#  'follows': 45,
#  'emergence': 1,
#  'structural': 8,
#  'changes': 43,
#  'following': 75,
#  'rise': 240,
#  'value': 106,
#  'yen': 193,
#  'decline': 74,
#  'domestic': 164,
#  'power': 30,
#  'planning': 24,
#  'work': 40,
#  'out': 148,
#  'revised': 45,
#  'through': 120,
#  'deliberations': 1,
#  'committee': 74,
#  'meetings': 29,
#  'agency': 38,
#  'natural': 50,
#  'resources': 43,
#  'review': 36,
#  'breakdown': 8,
#  'including': 101,
#  'oil': 586,
#  'nuclear': 2,
#  'gas': 158,
#  'provided': 25,
#  'bulk': 17,
#  'ended': 144,
#  'march': 315,
#  'supplying': 5,
#  'estimated': 105,
#  'kilowatt': 1,
#  'hour': 10,
#  'basis': 70,
#  'followed': 23,
#  'liquefied': 3,
#  'noted': 61,
#  'thai': 15,
#  'deficit': 213,
#  'widens': 3,
#  'quarter': 377,
#  'thailand': 27,
#  'widened': 6,
#  'baht': 3,
#  'ago': 129,
#  'economics': 9,
#  'department': 183,
#  'janunary': 1,
#  'rose': 227,
#  'climate': 4,
#  'resulted': 20,
#  'increase': 221,
#  'raw': 20,
#  'materials': 45,
#  'semi': 12,
#  'finished': 8,
#  'bill': 70,
#  'however': 137,
#  'fell': 126,
#  'prices': 387,
#  'expanded': 7,
#  'growth': 258,
#  'smaller': 17,
#  'than': 366,
#  'earnings': 177,
#  'key': 51,
#  'commodities': 30,
#  'rice': 72,
#  'declined': 61,
#  'maize': 41,
#  'sugar': 130,
#  'tin': 51,
#  'canned': 4,
#  'pineapples': 1,
#  'registering': 3,
#  'high': 150,
#  'were': 597,
#  'jewellery': 1,
#  'clothing': 4,
#  'rubber': 36,
#  'indonesia': 46,
#  'sees': 76,
#  'cpo': 5,
#  'price': 397,
#  'rising': 73,
#  'sharply': 46,
#  'expects': 98,
#  'crude': 160,
#  'palm': 32,
#  'tonne': 75,
#  'fob': 14,
#  'sometime': 3,
#  'better': 41,
#  'european': 121,
#  'fall': 111,
#  'malaysian': 11,
#  'hasrul': 1,
#  'harahap': 3,
#  'junior': 4,
#  'tree': 2,
#  'crops': 33,
#  'indonesian': 10,
#  'reporters': 47,
#  'sumatran': 1,
#  'now': 173,
#  'around': 164,
#  'cif': 7,
#  'delivery': 58,
#  'rotterdam': 13,
#  'traders': 133,
#  'maintain': 37,
#  'making': 73,
#  'recent': 102,
#  'purchases': 33,
#  'so': 103,
#  'possibly': 19,
#  'second': 82,
#  'producer': 59,
#  'after': 367,
#  'forced': 16,
#  'ensure': 9,
#  'during': 110,
#  'moslem': 1,
#  'fasting': 2,
#  'month': 250,
#  'ramadan': 2,
#  'cover': 28,
#  'temporary': 24,
#  'shortage': 20,
#  'lose': 7,
#  'calendar': 18,
#  'according': 54,
#  'central': 193,
#  'bank': 616,
#  'figures': 118,
#  'ship': 16,
#  'ban': 21,
#  'ends': 15,
#  'nsw': 10,
#  'ports': 18,
#  'tug': 5,
#  'crews': 3,
#  'wales': 5,
#  'victoria': 3,
#  'western': 68,
#  'lifted': 15,
#  'flag': 9,
#  'ships': 36,
#  'carrying': 12,
#  'containers': 2,
#  'still': 112,
#  'being': 97,
#  'disrupted': 7,
#  'separate': 19,
#  'shipping': 25,
#  'imposed': 26,
#  'pay': 151,
#  'claim': 8,
#  'prevented': 7,
#  'movement': 20,
#  'port': 50,
#  'nearly': 34,
#  'vessels': 20,
#  'went': 25,
#  'before': 141,
#  'hearing': 14,
#  'arbitration': 3,
#  'commission': 111,
#  'today': 275,
#  'disruption': 3,
#  'began': 46,
#  'cargo': 20,
#  'handling': 8,
#  'sydney': 5,
#  'newcastle': 3,
#  'kembla': 3,
#  'part': 96,
#  'called': 62,
#  'trades': 14,
#  'labour': 15,
#  'council': 58,
#  'protest': 9,
#  'state': 112,
#  'workers': 54,
#  'compensation': 12,
#  'laws': 14,
#  'various': 19,
#  'unions': 11,
#  'appear': 16,
#  'taking': 38,
#  'turn': 12,
#  'start': 100,
#  'shift': 10,
#  'then': 42,
#  'walk': 1,
#  'container': 4,
#  'movements': 9,
#  'most': 108,
#  'affected': 39,
#  'stopped': 9,
#  'altogether': 4,
#  'say': 97,
#  'how': 41,
#  'go': 43,
#  'what': 77,
#  'effect': 45,
#  'commodity': 49,
#  'may': 540,
#  'likely': 106,
#  'least': 45,
#  'paian': 1,
#  'nainggolan': 3,
#  'reuters': 92,
#  'telephone': 24,
#  'interview': 22,
#  'sawn': 1,
#  'timber': 5,
#  'pepper': 1,
#  'tobacco': 19,
#  'considered': 21,
#  'either': 22,
#  'refined': 23,
#  'introduced': 23,
#  'question': 19,
#  'rachmat': 1,
#  'saleh': 2,
#  'when': 169,
#  'ahead': 28,
#  'made': 174,
#  'fledgling': 1,
#  'currently': 57,
#  'coffee': 71,
#  'physicals': 3,
#  'outcry': 1,
#  'system': 102,
#  'four': 168,
#  'days': 128,
#  'several': 82,
#  'factors': 31,
#  'make': 91,
#  'cautiously': 2,
#  'slowly': 7,
#  'safely': 1,
#  'mistake': 2,
#  'undermine': 5,
#  'confidence': 21,
#  'physical': 9,
#  'added': 219,
#  'january': 106,
#  'contracts': 42,
#  'traded': 27,
#  'five': 245,
#  'forward': 29,
#  'robusta': 2,
#  'grades': 16,
#  'prompt': 2,
#  'board': 184,
#  'considering': 32,
#  'introduction': 10,
#  'futures': 64,
#  'later': 55,
#  'feasibility': 3,
#  'study': 28,
#  'needed': 50,
#  'decisions': 13,
#  'until': 62,
#  'elections': 6,
#  'monday': 25,
#  'should': 146,
#  'marketing': 72,
#  'hoped': 14,
#  'development': 89,
#  'help': 80,
#  'trying': 26,
#  'overseas': 25,
#  'building': 42,
#  'contacts': 5,
#  'users': 7,
#  'teams': 1,
#  'already': 82,
#  'encourage': 17,
#  'direct': 15,
#  'use': 119,
#  'delegation': 9,
#  'visit': 17,
#  'europe': 45,
#  'mexico': 22,
#  'latin': 4,
#  'states': 145,
#  'participation': 7,
#  'infant': 1,
#  'good': 71,
#  'although': 66,
#  'disappointing': 4,
#  'transactions': 24,
#  'december': 89,
#  'totalled': 26,
#  'worth': 51,
#  'plus': 32,
#  'rupiah': 3,
#  'delivered': 9,
#  'locally': 2,
#  'latest': 66,
#  'report': 209,
#  'amounted': 6,
#  'only': 175,
#  'lots': 4,
#  'valued': 15,
#  'total': 293,
#  'membership': 8,
#  'nine': 111,
#  'brokers': 25,
#  'sri': 14,
#  'lanka': 13,
#  'gets': 11,
#  'usda': 108,
#  'approval': 65,
#  'wheat': 189,
#  'food': 52,
#  'agriculture': 130,
#  'approved': 64,
#  'continental': 25,
#  'sale': 147,
#  'soft': 23,
#  'c': 76,
#  'f': 52,
#  'pacific': 39,
#  'northwest': 10,
#  'colombo': 6,
#  'shipment': 32,
#  'mining': 40,
#  'gold': 99,
#  'mine': 50,
#  'corp': 623,
#  'holdings': 56,
#  'wmng': 2,
#  'wmc': 6,
#  'establish': 5,
#  'joint': 55,
#  'venture': 46,
#  'northern': 19,
#  'territory': 2,
#  'about': 515,
#  'known': 23,
#  'goodall': 1,
#  'project': 14,
#  'owned': 125,
#  'local': 53,
#  'w': 17,
#  'r': 17,
#  'grace': 11,
#  'gra': 3,
#  'unit': 171,
#  'located': 15,
#  'kms': 2,
#  'east': 52,
#  'adelaide': 1,
#  'river': 23,
#  'mt': 11,
#  'bundey': 1,
#  'statement': 168,
#  'pit': 2,
#  'conventional': 3,
#  'leach': 1,
#  'treatment': 9,
#  'plant': 66,
#  'produce': 28,
#  'ounces': 17,
#  'mid': 26,
#  'annual': 101,
#  'ore': 24,
#  'capacity': 42,
#  'sumitomo': 16,
#  'aims': 6,
#  'quick': 7,
#  'recovery': 25,
#  'merger': 128,
#  'sumi': 1,
#  'certain': 63,
#  'status': 15,
#  'profitable': 21,
#  'result': 86,
#  'heiwa': 4,
#  'sogo': 4,
#  'analysts': 185,
#  'osaka': 2,
#  'based': 142,
#  'desposits': 1,
#  'trillion': 4,
#  'merged': 6,
#  'small': 40,
#  'struggling': 3,
#  'unrecoverable': 1,
#  'loans': 118,
#  'october': 53,
#  'link': 14,
#  'president': 137,
#  'koh': 1,
#  'komatsu': 9,
#  'confident': 9,
#  'his': 105,
#  'can': 116,
#  'regain': 1,
#  'position': 67,
#  'll': 4,
#  'back': 50,
#  'within': 63,
#  'three': 277,
#  'years': 159,
#  'initially': 8,
#  'profitability': 5,
#  'efficiency': 8,
#  'vastly': 1,
#  'branch': 10,
#  'network': 18,
#  'metropolitan': 4,
#  'area': 61,
#  'relatively': 16,
#  'weak': 24,
#  'divided': 9,
#  'whether': 52,
#  'gamble': 3,
#  'paid': 65,
#  'too': 53,
#  'debts': 4,
#  'others': 18,
#  'argue': 4,
#  'effective': 91,
#  'creating': 1,
#  'comparable': 10,
#  'scratch': 1,
#  'agreed': 155,
#  'aggressive': 8,
#  'entered': 32,
#  'lucrative': 4,
#  'securities': 151,
#  'geared': 2,
#  'competition': 21,
#  'questioned': 4,
#  'wisdom': 1,
#  'moves': 36,
#  've': 14,
#  'bold': 3,
#  'everything': 3,
#  'largely': 15,
#  'hands': 11,
#  'kleinwort': 5,
#  'benson': 2,
#  'simon': 3,
#  'smithson': 2,
#  'limits': 21,
#  'placed': 18,
#  'enter': 8,
#  'investment': 161,
#  'goldman': 5,
#  'sachs': 5,
#  'limited': 34,
#  'partnership': 30,
#  'federal': 145,
#  'reserve': 109,
#  'forbidden': 1,
#  'personnel': 7,
#  'tie': 4,
#  'widely': 7,
#  'looked': 5,
#  'lame': 1,
#  'duck': 1,
#  'fed': 165,
#  'stricter': 1,
#  'regulations': 12,
#  'change': 80,
#  'near': 41,
#  'future': 51,
#  'things': 7,
#  'wait': 4,
#  'st': 281,
#  'century': 13,
#  'willing': 13,
#  'patient': 4,
#  'routes': 7,
#  'into': 186,
#  'home': 43,
#  'article': 8,
#  'act': 32,
#  'version': 3,
#  'glass': 3,
#  'steagall': 1,
#  'separates': 2,
#  'banking': 54,
#  'walls': 1,
#  'crumbling': 1,
#  'hopes': 21,
#  'deregulation': 10,
#  'create': 7,
#  'opportunities': 12,
#  'need': 49,
#  'find': 22,
#  'chances': 5,
#  'cases': 12,
#  'these': 87,
#  'related': 28,
#  'trust': 56,
#  'occur': 10,
#  'focus': 16,
#  'bond': 50,
#  'dealing': 3,
#  'strengthening': 10,
#  'meiko': 1,
#  'holds': 32,
#  'optimistic': 18,
#  'entering': 8,
#  'here': 67,
#  'swiss': 40,
#  'universal': 8,
#  'subsidiary': 132,
#  'banca': 1,
#  'del': 9,
#  'gottardo': 2,
#  'finance': 112,
#  'grant': 6,
#  'licences': 12,
#  'subsidiaries': 19,
#  'banks': 149,
#  'soon': 36,
#  'parent': 26,
#  'less': 91,
#  'reluctant': 9,
#  'push': 14,
#  'don': 40,
#  'waves': 1,
#  'expect': 49,
#  'allowed': 22,
#  'like': 37,
#  'city': 38,
#  'pushing': 7,
#  'lending': 19,
#  'individuals': 8,
#  'medium': 27,
#  'businesses': 49,
#  'replace': 9,
#  'disappearing': 1,
#  'big': 15,
#  'devote': 1,
#  'lot': 16,
#  'digesting': 1,
#  'initiatives': 5,
#  'ailing': 3,
#  'strategies': 2,
#  'absorbing': 1,
#  'juggling': 1,
#  'next': 155,
#  'decade': 5,
#  'see': 58,
#  'strategy': 25,
#  'right': 33,
#  'wrong': 4,
#  'subroto': 3,
#  'supports': 6,
#  'extension': 24,
#  'mines': 25,
#  'confirmed': 22,
#  'support': 71,
#  'sixth': 10,
#  'agreement': 258,
#  'ita': 7,
#  'necessary': 24,
#  'clarify': 2,
#  'lapse': 2,
#  'ready': 15,
#  'seventh': 7,
#  'accord': 60,
#  'believe': 41,
#  'unnecessary': 2,
#  'expire': 17,
#  'june': 238,
#  'unless': 28,
#  'thirds': 5,
#  'majority': 24,
#  'members': 49,
#  'vote': 18,
#  'bundesbank': 84,
#  'allocates': 2,
#  'marks': 82,
#  'tender': 147,
#  'accepted': 23,
#  'bids': 33,
#  'repurchase': 49,
#  'fixed': 47,
#  ...}

# %%
counts = Counter(unigram_dict)
counts
# Out:
# Counter({'asian': 13,
#          'exporters': 52,
#          'fear': 8,
#          'damage': 29,
#          'from': 1369,
#          'u': 1117,
#          's': 2864,
#          'japan': 441,
#          'rift': 1,
#          'mounting': 5,
#          'trade': 549,
#          'friction': 8,
#          'between': 191,
#          'the': 12496,
#          'and': 4599,
#          'has': 974,
#          'raised': 70,
#          'fears': 13,
#          'among': 44,
#          'many': 54,
#          'of': 6671,
#          'asia': 14,
#          "'": 2094,
#          'exporting': 12,
#          'nations': 71,
#          'that': 1376,
#          'row': 3,
#          'could': 291,
#          'inflict': 1,
#          'far': 55,
#          'reaching': 7,
#          'economic': 244,
#          'businessmen': 15,
#          'officials': 190,
#          'said': 4649,
#          'they': 518,
#          'told': 237,
#          'reuter': 27,
#          'correspondents': 3,
#          'in': 5070,
#          'capitals': 3,
#          'a': 4412,
#          'move': 101,
#          'against': 270,
#          'might': 59,
#          'boost': 45,
#          'protectionist': 22,
#          'sentiment': 10,
#          'lead': 96,
#          'to': 6337,
#          'curbs': 12,
#          'on': 1643,
#          'american': 126,
#          'imports': 242,
#          'their': 230,
#          'products': 200,
#          'but': 650,
#          'some': 278,
#          'while': 164,
#          'conflict': 3,
#          'would': 926,
#          'hurt': 11,
#          'them': 58,
#          'long': 119,
#          'run': 21,
#          'short': 87,
#          'term': 120,
#          'tokyo': 75,
#          'loss': 607,
#          'be': 1165,
#          'gain': 101,
#          'it': 1970,
#          'will': 984,
#          'impose': 20,
#          'mln': 3064,
#          'dlrs': 2140,
#          'tariffs': 82,
#          'japanese': 192,
#          'electronics': 25,
#          'goods': 69,
#          'april': 477,
#          'retaliation': 20,
#          'for': 2592,
#          'alleged': 11,
#          'failure': 23,
#          'stick': 1,
#          'pact': 59,
#          'not': 838,
#          'sell': 139,
#          'semiconductors': 9,
#          'world': 166,
#          'markets': 182,
#          'at': 1311,
#          'below': 66,
#          'cost': 86,
#          'unofficial': 1,
#          'estimates': 62,
#          'put': 59,
#          'impact': 52,
#          'billion': 1112,
#          'spokesmen': 3,
#          'major': 206,
#          'firms': 57,
#          'virtually': 14,
#          'halt': 10,
#          'exports': 294,
#          'hit': 37,
#          'by': 1375,
#          'new': 474,
#          'taxes': 29,
#          'we': 258,
#          'wouldn': 6,
#          't': 115,
#          'able': 31,
#          'do': 90,
#          'business': 171,
#          'spokesman': 166,
#          'leading': 49,
#          'firm': 114,
#          'matsushita': 1,
#          'electric': 35,
#          'industrial': 120,
#          'co': 370,
#          'ltd': 273,
#          'lt': 1498,
#          'mc': 1,
#          'if': 282,
#          'remain': 55,
#          'place': 31,
#          'any': 142,
#          'length': 1,
#          'time': 145,
#          'beyond': 12,
#          'few': 42,
#          'months': 164,
#          'mean': 11,
#          'complete': 22,
#          'erosion': 2,
#          'subject': 72,
#          'tom': 4,
#          'murtha': 1,
#          'stock': 394,
#          'analyst': 60,
#          'office': 44,
#          'broker': 21,
#          'james': 33,
#          'capel': 2,
#          'taiwan': 62,
#          'are': 625,
#          'also': 442,
#          'worried': 15,
#          'aware': 7,
#          'seriousness': 3,
#          'threat': 11,
#          'because': 214,
#          'serves': 3,
#          'as': 884,
#          'warning': 5,
#          'us': 41,
#          'senior': 40,
#          'taiwanese': 4,
#          'official': 174,
#          'who': 98,
#          'asked': 74,
#          'named': 38,
#          'had': 512,
#          'surplus': 155,
#          'last': 654,
#          'year': 1212,
#          'pct': 1811,
#          'with': 1127,
#          'helped': 21,
#          'swell': 2,
#          'foreign': 253,
#          'exchange': 279,
#          'reserves': 153,
#          'largest': 79,
#          'must': 46,
#          'quickly': 18,
#          'open': 98,
#          'our': 101,
#          'remove': 9,
#          'barriers': 12,
#          'cut': 206,
#          'import': 67,
#          'allow': 40,
#          'want': 43,
#          'defuse': 2,
#          'problems': 55,
#          'possible': 72,
#          'paul': 21,
#          'sheen': 1,
#          'chairman': 145,
#          'textile': 32,
#          'safe': 3,
#          'group': 342,
#          'south': 135,
#          'korea': 49,
#          'promotion': 5,
#          'association': 53,
#          'dispute': 24,
#          'pressure': 57,
#          'whose': 21,
#          'chief': 51,
#          'similar': 36,
#          'those': 75,
#          'up': 386,
#          'malaysia': 21,
#          'officers': 17,
#          'tough': 23,
#          'hard': 37,
#          'producers': 72,
#          'third': 67,
#          'countries': 142,
#          'expand': 25,
#          'sales': 371,
#          'hong': 26,
#          'kong': 26,
#          'where': 60,
#          'newspapers': 5,
#          'have': 542,
#          'been': 396,
#          'selling': 42,
#          'manufacturers': 15,
#          'share': 516,
#          'view': 40,
#          'other': 331,
#          'such': 100,
#          'commercial': 41,
#          'advantage': 8,
#          'outweighed': 2,
#          'further': 172,
#          'block': 19,
#          'is': 1420,
#          'very': 72,
#          'lawrence': 2,
#          'mills': 17,
#          'director': 41,
#          'general': 86,
#          'federation': 20,
#          'industry': 200,
#          'whole': 20,
#          'purpose': 9,
#          'prevent': 30,
#          'one': 508,
#          'day': 132,
#          'extended': 19,
#          'sources': 161,
#          'much': 92,
#          'more': 354,
#          'serious': 13,
#          'disadvantage': 2,
#          'action': 82,
#          'restraining': 2,
#          'he': 971,
#          'was': 1127,
#          'biggest': 24,
#          'export': 152,
#          'market': 498,
#          'accounting': 24,
#          'over': 236,
#          'domestically': 5,
#          'produced': 45,
#          'australian': 56,
#          'government': 304,
#          'awaiting': 9,
#          'outcome': 12,
#          'talks': 112,
#          'interest': 252,
#          'concern': 39,
#          'minister': 122,
#          'john': 24,
#          'button': 2,
#          'canberra': 1,
#          'friday': 44,
#          'this': 642,
#          'kind': 13,
#          'deterioration': 6,
#          'relations': 13,
#          'two': 444,
#          'which': 643,
#          'trading': 141,
#          'partners': 57,
#          'ours': 2,
#          'matter': 16,
#          'australia': 55,
#          'concerns': 9,
#          'centred': 1,
#          'coal': 7,
#          'beef': 57,
#          'significant': 34,
#          'country': 103,
#          'meanwhile': 13,
#          'diplomatic': 10,
#          'manoeuvres': 1,
#          'solve': 5,
#          'stand': 14,
#          'off': 89,
#          'continue': 84,
#          'ruling': 30,
#          'liberal': 18,
#          'democratic': 17,
#          'party': 34,
#          'yesterday': 161,
#          'outlined': 12,
#          'package': 34,
#          'measures': 67,
#          'economy': 125,
#          'proposed': 106,
#          'include': 65,
#          'large': 70,
#          'supplementary': 5,
#          'budget': 117,
#          'record': 188,
#          'public': 84,
#          'works': 12,
#          'spending': 54,
#          'first': 447,
#          'half': 113,
#          'financial': 148,
#          'call': 28,
#          'stepped': 2,
#          'an': 844,
#          'emergency': 10,
#          'measure': 16,
#          'stimulate': 27,
#          'despite': 71,
#          'prime': 73,
#          'yasuhiro': 12,
#          'nakasone': 24,
#          'avowed': 1,
#          'fiscal': 90,
#          'reform': 31,
#          'program': 66,
#          'deputy': 16,
#          'representative': 19,
#          'michael': 12,
#          'smith': 12,
#          'makoto': 3,
#          'kuroda': 9,
#          'international': 221,
#          'miti': 17,
#          'due': 160,
#          'meet': 63,
#          'washington': 92,
#          'week': 334,
#          'effort': 31,
#          'end': 275,
#          'china': 106,
#          'daily': 65,
#          'says': 143,
#          'vermin': 2,
#          'eat': 2,
#          'grain': 130,
#          'stocks': 177,
#          'survey': 8,
#          'provinces': 6,
#          'seven': 147,
#          'cities': 4,
#          'showed': 48,
#          'consume': 3,
#          'each': 119,
#          'tonnes': 535,
#          'or': 553,
#          'fruit': 3,
#          'output': 107,
#          'left': 28,
#          'rot': 3,
#          'its': 1372,
#          'vegetables': 4,
#          'paper': 27,
#          'blamed': 7,
#          'waste': 14,
#          'inadequate': 10,
#          'storage': 18,
#          'bad': 6,
#          'preservation': 2,
#          'methods': 6,
#          'launched': 20,
#          'national': 197,
#          'programme': 13,
#          'reduce': 77,
#          'calling': 10,
#          'improved': 41,
#          'technology': 40,
#          'greater': 23,
#          'production': 289,
#          'additives': 2,
#          'gave': 44,
#          'no': 277,
#          'details': 57,
#          'revise': 8,
#          'energy': 93,
#          'demand': 177,
#          'downwards': 4,
#          'ministry': 108,
#          'supply': 158,
#          'outlook': 28,
#          'august': 39,
#          'forecast': 96,
#          'downtrend': 2,
#          'expected': 274,
#          'lower': 152,
#          'projection': 6,
#          'primary': 26,
#          'supplies': 60,
#          'kilolitres': 1,
#          'kl': 2,
#          'decision': 70,
#          'follows': 45,
#          'emergence': 1,
#          'structural': 8,
#          'changes': 43,
#          'following': 75,
#          'rise': 240,
#          'value': 106,
#          'yen': 193,
#          'decline': 74,
#          'domestic': 164,
#          'power': 30,
#          'planning': 24,
#          'work': 40,
#          'out': 148,
#          'revised': 45,
#          'through': 120,
#          'deliberations': 1,
#          'committee': 74,
#          'meetings': 29,
#          'agency': 38,
#          'natural': 50,
#          'resources': 43,
#          'review': 36,
#          'breakdown': 8,
#          'including': 101,
#          'oil': 586,
#          'nuclear': 2,
#          'gas': 158,
#          'provided': 25,
#          'bulk': 17,
#          'ended': 144,
#          'march': 315,
#          'supplying': 5,
#          'estimated': 105,
#          'kilowatt': 1,
#          'hour': 10,
#          'basis': 70,
#          'followed': 23,
#          'liquefied': 3,
#          'noted': 61,
#          'thai': 15,
#          'deficit': 213,
#          'widens': 3,
#          'quarter': 377,
#          'thailand': 27,
#          'widened': 6,
#          'baht': 3,
#          'ago': 129,
#          'economics': 9,
#          'department': 183,
#          'janunary': 1,
#          'rose': 227,
#          'climate': 4,
#          'resulted': 20,
#          'increase': 221,
#          'raw': 20,
#          'materials': 45,
#          'semi': 12,
#          'finished': 8,
#          'bill': 70,
#          'however': 137,
#          'fell': 126,
#          'prices': 387,
#          'expanded': 7,
#          'growth': 258,
#          'smaller': 17,
#          'than': 366,
#          'earnings': 177,
#          'key': 51,
#          'commodities': 30,
#          'rice': 72,
#          'declined': 61,
#          'maize': 41,
#          'sugar': 130,
#          'tin': 51,
#          'canned': 4,
#          'pineapples': 1,
#          'registering': 3,
#          'high': 150,
#          'were': 597,
#          'jewellery': 1,
#          'clothing': 4,
#          'rubber': 36,
#          'indonesia': 46,
#          'sees': 76,
#          'cpo': 5,
#          'price': 397,
#          'rising': 73,
#          'sharply': 46,
#          'expects': 98,
#          'crude': 160,
#          'palm': 32,
#          'tonne': 75,
#          'fob': 14,
#          'sometime': 3,
#          'better': 41,
#          'european': 121,
#          'fall': 111,
#          'malaysian': 11,
#          'hasrul': 1,
#          'harahap': 3,
#          'junior': 4,
#          'tree': 2,
#          'crops': 33,
#          'indonesian': 10,
#          'reporters': 47,
#          'sumatran': 1,
#          'now': 173,
#          'around': 164,
#          'cif': 7,
#          'delivery': 58,
#          'rotterdam': 13,
#          'traders': 133,
#          'maintain': 37,
#          'making': 73,
#          'recent': 102,
#          'purchases': 33,
#          'so': 103,
#          'possibly': 19,
#          'second': 82,
#          'producer': 59,
#          'after': 367,
#          'forced': 16,
#          'ensure': 9,
#          'during': 110,
#          'moslem': 1,
#          'fasting': 2,
#          'month': 250,
#          'ramadan': 2,
#          'cover': 28,
#          'temporary': 24,
#          'shortage': 20,
#          'lose': 7,
#          'calendar': 18,
#          'according': 54,
#          'central': 193,
#          'bank': 616,
#          'figures': 118,
#          'ship': 16,
#          'ban': 21,
#          'ends': 15,
#          'nsw': 10,
#          'ports': 18,
#          'tug': 5,
#          'crews': 3,
#          'wales': 5,
#          'victoria': 3,
#          'western': 68,
#          'lifted': 15,
#          'flag': 9,
#          'ships': 36,
#          'carrying': 12,
#          'containers': 2,
#          'still': 112,
#          'being': 97,
#          'disrupted': 7,
#          'separate': 19,
#          'shipping': 25,
#          'imposed': 26,
#          'pay': 151,
#          'claim': 8,
#          'prevented': 7,
#          'movement': 20,
#          'port': 50,
#          'nearly': 34,
#          'vessels': 20,
#          'went': 25,
#          'before': 141,
#          'hearing': 14,
#          'arbitration': 3,
#          'commission': 111,
#          'today': 275,
#          'disruption': 3,
#          'began': 46,
#          'cargo': 20,
#          'handling': 8,
#          'sydney': 5,
#          'newcastle': 3,
#          'kembla': 3,
#          'part': 96,
#          'called': 62,
#          'trades': 14,
#          'labour': 15,
#          'council': 58,
#          'protest': 9,
#          'state': 112,
#          'workers': 54,
#          'compensation': 12,
#          'laws': 14,
#          'various': 19,
#          'unions': 11,
#          'appear': 16,
#          'taking': 38,
#          'turn': 12,
#          'start': 100,
#          'shift': 10,
#          'then': 42,
#          'walk': 1,
#          'container': 4,
#          'movements': 9,
#          'most': 108,
#          'affected': 39,
#          'stopped': 9,
#          'altogether': 4,
#          'say': 97,
#          'how': 41,
#          'go': 43,
#          'what': 77,
#          'effect': 45,
#          'commodity': 49,
#          'may': 540,
#          'likely': 106,
#          'least': 45,
#          'paian': 1,
#          'nainggolan': 3,
#          'reuters': 92,
#          'telephone': 24,
#          'interview': 22,
#          'sawn': 1,
#          'timber': 5,
#          'pepper': 1,
#          'tobacco': 19,
#          'considered': 21,
#          'either': 22,
#          'refined': 23,
#          'introduced': 23,
#          'question': 19,
#          'rachmat': 1,
#          'saleh': 2,
#          'when': 169,
#          'ahead': 28,
#          'made': 174,
#          'fledgling': 1,
#          'currently': 57,
#          'coffee': 71,
#          'physicals': 3,
#          'outcry': 1,
#          'system': 102,
#          'four': 168,
#          'days': 128,
#          'several': 82,
#          'factors': 31,
#          'make': 91,
#          'cautiously': 2,
#          'slowly': 7,
#          'safely': 1,
#          'mistake': 2,
#          'undermine': 5,
#          'confidence': 21,
#          'physical': 9,
#          'added': 219,
#          'january': 106,
#          'contracts': 42,
#          'traded': 27,
#          'five': 245,
#          'forward': 29,
#          'robusta': 2,
#          'grades': 16,
#          'prompt': 2,
#          'board': 184,
#          'considering': 32,
#          'introduction': 10,
#          'futures': 64,
#          'later': 55,
#          'feasibility': 3,
#          'study': 28,
#          'needed': 50,
#          'decisions': 13,
#          'until': 62,
#          'elections': 6,
#          'monday': 25,
#          'should': 146,
#          'marketing': 72,
#          'hoped': 14,
#          'development': 89,
#          'help': 80,
#          'trying': 26,
#          'overseas': 25,
#          'building': 42,
#          'contacts': 5,
#          'users': 7,
#          'teams': 1,
#          'already': 82,
#          'encourage': 17,
#          'direct': 15,
#          'use': 119,
#          'delegation': 9,
#          'visit': 17,
#          'europe': 45,
#          'mexico': 22,
#          'latin': 4,
#          'states': 145,
#          'participation': 7,
#          'infant': 1,
#          'good': 71,
#          'although': 66,
#          'disappointing': 4,
#          'transactions': 24,
#          'december': 89,
#          'totalled': 26,
#          'worth': 51,
#          'plus': 32,
#          'rupiah': 3,
#          'delivered': 9,
#          'locally': 2,
#          'latest': 66,
#          'report': 209,
#          'amounted': 6,
#          'only': 175,
#          'lots': 4,
#          'valued': 15,
#          'total': 293,
#          'membership': 8,
#          'nine': 111,
#          'brokers': 25,
#          'sri': 14,
#          'lanka': 13,
#          'gets': 11,
#          'usda': 108,
#          'approval': 65,
#          'wheat': 189,
#          'food': 52,
#          'agriculture': 130,
#          'approved': 64,
#          'continental': 25,
#          'sale': 147,
#          'soft': 23,
#          'c': 76,
#          'f': 52,
#          'pacific': 39,
#          'northwest': 10,
#          'colombo': 6,
#          'shipment': 32,
#          'mining': 40,
#          'gold': 99,
#          'mine': 50,
#          'corp': 623,
#          'holdings': 56,
#          'wmng': 2,
#          'wmc': 6,
#          'establish': 5,
#          'joint': 55,
#          'venture': 46,
#          'northern': 19,
#          'territory': 2,
#          'about': 515,
#          'known': 23,
#          'goodall': 1,
#          'project': 14,
#          'owned': 125,
#          'local': 53,
#          'w': 17,
#          'r': 17,
#          'grace': 11,
#          'gra': 3,
#          'unit': 171,
#          'located': 15,
#          'kms': 2,
#          'east': 52,
#          'adelaide': 1,
#          'river': 23,
#          'mt': 11,
#          'bundey': 1,
#          'statement': 168,
#          'pit': 2,
#          'conventional': 3,
#          'leach': 1,
#          'treatment': 9,
#          'plant': 66,
#          'produce': 28,
#          'ounces': 17,
#          'mid': 26,
#          'annual': 101,
#          'ore': 24,
#          'capacity': 42,
#          'sumitomo': 16,
#          'aims': 6,
#          'quick': 7,
#          'recovery': 25,
#          'merger': 128,
#          'sumi': 1,
#          'certain': 63,
#          'status': 15,
#          'profitable': 21,
#          'result': 86,
#          'heiwa': 4,
#          'sogo': 4,
#          'analysts': 185,
#          'osaka': 2,
#          'based': 142,
#          'desposits': 1,
#          'trillion': 4,
#          'merged': 6,
#          'small': 40,
#          'struggling': 3,
#          'unrecoverable': 1,
#          'loans': 118,
#          'october': 53,
#          'link': 14,
#          'president': 137,
#          'koh': 1,
#          'komatsu': 9,
#          'confident': 9,
#          'his': 105,
#          'can': 116,
#          'regain': 1,
#          'position': 67,
#          'll': 4,
#          'back': 50,
#          'within': 63,
#          'three': 277,
#          'years': 159,
#          'initially': 8,
#          'profitability': 5,
#          'efficiency': 8,
#          'vastly': 1,
#          'branch': 10,
#          'network': 18,
#          'metropolitan': 4,
#          'area': 61,
#          'relatively': 16,
#          'weak': 24,
#          'divided': 9,
#          'whether': 52,
#          'gamble': 3,
#          'paid': 65,
#          'too': 53,
#          'debts': 4,
#          'others': 18,
#          'argue': 4,
#          'effective': 91,
#          'creating': 1,
#          'comparable': 10,
#          'scratch': 1,
#          'agreed': 155,
#          'aggressive': 8,
#          'entered': 32,
#          'lucrative': 4,
#          'securities': 151,
#          'geared': 2,
#          'competition': 21,
#          'questioned': 4,
#          'wisdom': 1,
#          'moves': 36,
#          've': 14,
#          'bold': 3,
#          'everything': 3,
#          'largely': 15,
#          'hands': 11,
#          'kleinwort': 5,
#          'benson': 2,
#          'simon': 3,
#          'smithson': 2,
#          'limits': 21,
#          'placed': 18,
#          'enter': 8,
#          'investment': 161,
#          'goldman': 5,
#          'sachs': 5,
#          'limited': 34,
#          'partnership': 30,
#          'federal': 145,
#          'reserve': 109,
#          'forbidden': 1,
#          'personnel': 7,
#          'tie': 4,
#          'widely': 7,
#          'looked': 5,
#          'lame': 1,
#          'duck': 1,
#          'fed': 165,
#          'stricter': 1,
#          'regulations': 12,
#          'change': 80,
#          'near': 41,
#          'future': 51,
#          'things': 7,
#          'wait': 4,
#          'st': 281,
#          'century': 13,
#          'willing': 13,
#          'patient': 4,
#          'routes': 7,
#          'into': 186,
#          'home': 43,
#          'article': 8,
#          'act': 32,
#          'version': 3,
#          'glass': 3,
#          'steagall': 1,
#          'separates': 2,
#          'banking': 54,
#          'walls': 1,
#          'crumbling': 1,
#          'hopes': 21,
#          'deregulation': 10,
#          'create': 7,
#          'opportunities': 12,
#          'need': 49,
#          'find': 22,
#          'chances': 5,
#          'cases': 12,
#          'these': 87,
#          'related': 28,
#          'trust': 56,
#          'occur': 10,
#          'focus': 16,
#          'bond': 50,
#          'dealing': 3,
#          'strengthening': 10,
#          'meiko': 1,
#          'holds': 32,
#          'optimistic': 18,
#          'entering': 8,
#          'here': 67,
#          'swiss': 40,
#          'universal': 8,
#          'subsidiary': 132,
#          'banca': 1,
#          'del': 9,
#          'gottardo': 2,
#          'finance': 112,
#          'grant': 6,
#          'licences': 12,
#          'subsidiaries': 19,
#          'banks': 149,
#          'soon': 36,
#          'parent': 26,
#          'less': 91,
#          'reluctant': 9,
#          'push': 14,
#          'don': 40,
#          'waves': 1,
#          'expect': 49,
#          'allowed': 22,
#          'like': 37,
#          'city': 38,
#          'pushing': 7,
#          'lending': 19,
#          'individuals': 8,
#          'medium': 27,
#          'businesses': 49,
#          'replace': 9,
#          'disappearing': 1,
#          'big': 15,
#          'devote': 1,
#          'lot': 16,
#          'digesting': 1,
#          'initiatives': 5,
#          'ailing': 3,
#          'strategies': 2,
#          'absorbing': 1,
#          'juggling': 1,
#          'next': 155,
#          'decade': 5,
#          'see': 58,
#          'strategy': 25,
#          'right': 33,
#          'wrong': 4,
#          'subroto': 3,
#          'supports': 6,
#          'extension': 24,
#          'mines': 25,
#          'confirmed': 22,
#          'support': 71,
#          'sixth': 10,
#          'agreement': 258,
#          'ita': 7,
#          'necessary': 24,
#          'clarify': 2,
#          'lapse': 2,
#          'ready': 15,
#          'seventh': 7,
#          'accord': 60,
#          'believe': 41,
#          'unnecessary': 2,
#          'expire': 17,
#          'june': 238,
#          'unless': 28,
#          'thirds': 5,
#          'majority': 24,
#          'members': 49,
#          'vote': 18,
#          'bundesbank': 84,
#          'allocates': 2,
#          'marks': 82,
#          'tender': 147,
#          'accepted': 23,
#          'bids': 33,
#          'repurchase': 49,
#          'fixed': 47,
#          ...})

# %%
total_count = sum(unigram_dict.values())
total_count
# Out:
# 241583

# %%
for word in counts:
  counts[word] /= float(total_count)

counts
# Out:
# Counter({'asian': 5.3811733441508716e-05,
#          'exporters': 0.00021524693376603486,
#          'fear': 3.311491288708229e-05,
#          'damage': 0.00012004155921567329,
#          'from': 0.005666789467801956,
#          'u': 0.004623669711858864,
#          's': 0.011855138813575458,
#          'japan': 0.0018254595729004111,
#          'rift': 4.139364110885286e-06,
#          'mounting': 2.0696820554426428e-05,
#          'trade': 0.002272510896876022,
#          'friction': 3.311491288708229e-05,
#          'between': 0.0007906185451790896,
#          'the': 0.05172549392962253,
#          'and': 0.01903693554596143,
#          'has': 0.004031740644002268,
#          'raised': 0.00028975548776197,
#          'fears': 5.3811733441508716e-05,
#          'among': 0.00018213202087895256,
#          'many': 0.00022352566198780545,
#          'of': 0.02761369798371574,
#          'asia': 5.7951097552394e-05,
#          "'": 0.008667828448193788,
#          'exporting': 4.967236933062343e-05,
#          'nations': 0.0002938948518728553,
#          'that': 0.005695765016578153,
#          'row': 1.2418092332655858e-05,
#          'could': 0.001204554956267618,
#          'inflict': 4.139364110885286e-06,
#          'far': 0.00022766502609869072,
#          'reaching': 2.8975548776197e-05,
#          'economic': 0.0010100048430560097,
#          'businessmen': 6.209046166327928e-05,
#          'officials': 0.0007864791810682044,
#          'said': 0.019243903751505694,
#          'they': 0.002144190609438578,
#          'told': 0.0009810292942798128,
#          'reuter': 0.00011176283099390272,
#          'correspondents': 1.2418092332655858e-05,
#          'in': 0.0209865760421884,
#          'capitals': 1.2418092332655858e-05,
#          'a': 0.01826287445722588,
#          'move': 0.00041807577519941384,
#          'against': 0.0011176283099390272,
#          'might': 0.00024422248254223186,
#          'boost': 0.00018627138498983787,
#          'protectionist': 9.106601043947628e-05,
#          'sentiment': 4.1393641108852856e-05,
#          'lead': 0.00039737895464498745,
#          'to': 0.026231150370680058,
#          'curbs': 4.967236933062343e-05,
#          'on': 0.006800975234184525,
#          'american': 0.000521559877971546,
#          'imports': 0.0010017261148342392,
#          'their': 0.0009520537455036158,
#          'products': 0.0008278728221770571,
#          'but': 0.0026905866720754357,
#          'some': 0.0011507432228261094,
#          'while': 0.0006788557141851869,
#          'conflict': 1.2418092332655858e-05,
#          'would': 0.0038330511666797747,
#          'hurt': 4.553300521973814e-05,
#          'them': 0.00024008311843134658,
#          'long': 0.000492584329195349,
#          'run': 8.6926646328591e-05,
#          'short': 0.00036012467764701985,
#          'term': 0.0004967236933062343,
#          'tokyo': 0.0003104523083163964,
#          'loss': 0.0025125940153073686,
#          'be': 0.004822359189181358,
#          'gain': 0.00041807577519941384,
#          'it': 0.008154547298444012,
#          'will': 0.004073134285111121,
#          'impose': 8.278728221770571e-05,
#          'mln': 0.012683011635752516,
#          'dlrs': 0.008858239197294511,
#          'tariffs': 0.00033942785709259346,
#          'japanese': 0.0007947579092899749,
#          'electronics': 0.00010348410277213214,
#          'goods': 0.00028561612365108474,
#          'april': 0.0019744766808922815,
#          'retaliation': 8.278728221770571e-05,
#          'for': 0.01072923177541466,
#          'alleged': 4.553300521973814e-05,
#          'tender': 0.000608486524300137,
#          'accepted': 9.520537455036157e-05,
#          'bids': 0.00013659901565921443,
#          'repurchase': 0.000202828841433379,
#          'fixed': 0.00019455011321160842,
#          ...})

# %% [markdown]
# ## **Find the probabilty of occurence of a word given previous two words**

# %%
for w1_w2 in model:
  total_count = float(sum(model[w1_w2].values()))
  for w3 in model[w1_w2]:
    model[w1_w2][w3] /= total_count

# %%
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('asian',
#               'exporters'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fear': 1.0}),
#              ('exporters',
#               'fear'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'damage': 1.0}),
#              ('fear',
#               'damage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'from': 1.0}),
#              ('damage',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.5,
#                           'local': 0.5}),
#              ('from',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.8333333333333334,
#                           'k': 0.16666666666666666}),
#              ('u',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'japan': 0.006586169045005488,
#                           'and': 0.03732162458836443,
#                           'move': 0.0010976948408342481,
#                           'has': 0.007683863885839737,
#                           'said': 0.0043907793633369925,
#                           'products': 0.005488474204171241,
#                           'up': 0.0021953896816684962,
#                           'pressure': 0.003293084522502744,
#                           'last': 0.005488474204171241,
#                           'exports': 0.008781558726673985,
#                           'japanese': 0.005488474204171241,
#                           'trade': 0.048298572996706916,
#                           'department': 0.003293084522502744,
#                           'dlrs': 0.03951701427003293,
#                           'securities': 0.0021953896816684962,
#                           'glass': 0.0010976948408342481,
#                           'commercial': 0.0010976948408342481,
#                           'officials': 0.03293084522502744,
#                           'farm': 0.006586169045005488,
#                           'would': 0.005488474204171241,
#                           'to': 0.006586169045005488,
#                           'he': 0.0043907793633369925,
#                           'agriculture': 0.07903402854006586,
#                           'market': 0.007683863885839737,
#                           'corn': 0.013172338090010977,
#                           'will': 0.0021953896816684962,
#                           'feedgrain': 0.0010976948408342481,
#                           'which': 0.0021953896816684962,
#                           'limit': 0.0010976948408342481,
#                           'based': 0.0021953896816684962,
#                           'currency': 0.014270032930845226,
#                           'sanctions': 0.003293084522502744,
#                           'official': 0.003293084522502744,
#                           'not': 0.003293084522502744,
#                           'hopes': 0.0021953896816684962,
#                           'investors': 0.0010976948408342481,
#                           'dollar': 0.026344676180021953,
#                           'unit': 0.003293084522502744,
#                           'where': 0.006586169045005488,
#                           'charges': 0.0010976948408342481,
#                           'decision': 0.0010976948408342481,
#                           'chip': 0.0021953896816684962,
#                           'concern': 0.0010976948408342481,
#                           'complaint': 0.0010976948408342481,
#                           'banking': 0.0043907793633369925,
#                           'treasury': 0.010976948408342482,
#                           'petrochemical': 0.0021953896816684962,
#                           'chemical': 0.003293084522502744,
#                           'economy': 0.013172338090010977,
#                           'dlr': 0.009879253567508232,
#                           'textile': 0.006586169045005488,
#                           'investor': 0.0010976948408342481,
#                           'defense': 0.0043907793633369925,
#                           'government': 0.012074643249176729,
#                           'no': 0.0021953896816684962,
#                           'a': 0.006586169045005488,
#                           'parent': 0.0010976948408342481,
#                           'acquisition': 0.0010976948408342481,
#                           'tariffs': 0.0043907793633369925,
#                           'semiconductor': 0.003293084522502744,
#                           'firms': 0.0043907793633369925,
#                           'purchase': 0.0010976948408342481,
#                           'medical': 0.0021953896816684962,
#                           'reflected': 0.0010976948408342481,
#                           'budget': 0.0043907793633369925,
#                           'is': 0.003293084522502744,
#                           'hurting': 0.0010976948408342481,
#                           'calls': 0.003293084522502744,
#                           'machinery': 0.0021953896816684962,
#                           'green': 0.0010976948408342481,
#                           'roastings': 0.0010976948408342481,
#                           'european': 0.0010976948408342481,
#                           'u': 0.0010976948408342481,
#                           'bond': 0.0010976948408342481,
#                           'richards': 0.0010976948408342481,
#                           'companies': 0.0021953896816684962,
#                           'rate': 0.0010976948408342481,
#                           'monetary': 0.0043907793633369925,
#                           'industry': 0.003293084522502744,
#                           'mln': 0.0010976948408342481,
#                           'feeder': 0.0021953896816684962,
#                           'bancorp': 0.005488474204171241,
#                           'employees': 0.0010976948408342481,
#                           'trust': 0.006586169045005488,
#                           'by': 0.0021953896816684962,
#                           'underwriters': 0.0010976948408342481,
#                           'revenues': 0.0010976948408342481,
#                           'it': 0.0010976948408342481,
#                           'on': 0.005488474204171241,
#                           'sets': 0.0010976948408342481,
#                           'sprint': 0.0010976948408342481,
#                           'gas': 0.0010976948408342481,
#                           'competitors': 0.0010976948408342481,
#                           'plants': 0.003293084522502744,
#                           'cattle': 0.0021953896816684962,
#                           'banks': 0.003293084522502744,
#                           'inflation': 0.0010976948408342481,
#                           'east': 0.0010976948408342481,
#                           'rice': 0.0021953896816684962,
#                           'agricultural': 0.003293084522502744,
#                           'agency': 0.0010976948408342481,
#                           'international': 0.0010976948408342481,
#                           'customs': 0.0010976948408342481,
#                           'bankrupcty': 0.0010976948408342481,
#                           'supreme': 0.0010976948408342481,
#                           'bid': 0.0010976948408342481,
#                           'believed': 0.0010976948408342481,
#                           'bill': 0.0010976948408342481,
#                           'soybeans': 0.005488474204171241,
#                           'commerce': 0.0043907793633369925,
#                           'urges': 0.0021953896816684962,
#                           'they': 0.0021953896816684962,
#                           'rose': 0.003293084522502744,
#                           'the': 0.0021953896816684962,
#                           'proposal': 0.0010976948408342481,
#                           'foodgrains': 0.0010976948408342481,
#                           'reprisals': 0.0010976948408342481,
#                           'goods': 0.003293084522502744,
#                           'china': 0.0010976948408342481,
#                           'rules': 0.0010976948408342481,
#                           'support': 0.0010976948408342481,
#                           'retaliation': 0.0010976948408342481,
#                           'central': 0.0010976948408342481,
#                           'business': 0.0010976948408342481,
#                           'trading': 0.0021953896816684962,
#                           'arm': 0.0010976948408342481,
#                           'gnp': 0.0010976948408342481,
#                           'south': 0.0021953896816684962,
#                           'had': 0.0021953896816684962,
#                           'study': 0.0010976948408342481,
#                           'consumer': 0.003293084522502744,
#                           'industrial': 0.0010976948408342481,
#                           'industries': 0.0010976948408342481,
#                           'manufacturing': 0.0010976948408342481,
#                           'district': 0.006586169045005488,
#                           'rig': 0.0010976948408342481,
#                           'drilling': 0.0010976948408342481,
#                           'countervailing': 0.0010976948408342481,
#                           'or': 0.0010976948408342481,
#                           'zimmerman': 0.0010976948408342481,
#                           'forest': 0.0010976948408342481,
#                           'system': 0.0010976948408342481,
#                           'in': 0.0021953896816684962,
#                           'lumbermen': 0.0010976948408342481,
#                           'lumber': 0.0010976948408342481,
#                           'justice': 0.0010976948408342481,
#                           'publishing': 0.0010976948408342481,
#                           'video': 0.0043907793633369925,
#                           'allies': 0.0021953896816684962,
#                           'frigate': 0.003293084522502744,
#                           'thrift': 0.003293084522502744,
#                           'unprepared': 0.0010976948408342481,
#                           'participation': 0.0010976948408342481,
#                           'military': 0.0043907793633369925,
#                           'action': 0.0010976948408342481,
#                           'court': 0.0043907793633369925,
#                           'be': 0.0010976948408342481,
#                           'hart': 0.0010976948408342481,
#                           'did': 0.0010976948408342481,
#                           'firm': 0.0021953896816684962,
#                           'sectors': 0.0010976948408342481,
#                           'investment': 0.0010976948408342481,
#                           'should': 0.0010976948408342481,
#                           'gold': 0.0021953896816684962,
#                           'salmonellosis': 0.0010976948408342481,
#                           'house': 0.007683863885839737,
#                           'allegis': 0.0010976948408342481,
#                           'weighs': 0.0010976948408342481,
#                           'domestic': 0.0010976948408342481,
#                           "'": 0.0010976948408342481,
#                           'analysts': 0.0010976948408342481,
#                           'stocks': 0.0021953896816684962,
#                           'secretary': 0.0021953896816684962,
#                           'might': 0.0010976948408342481,
#                           'could': 0.0021953896816684962,
#                           'feed': 0.0010976948408342481,
#                           'flag': 0.003293084522502744,
#                           'arms': 0.0021953896816684962,
#                           'warships': 0.003293084522502744,
#                           'inc': 0.0010976948408342481,
#                           'holding': 0.0010976948408342481,
#                           'barley': 0.0021953896816684962,
#                           'flags': 0.0021953896816684962,
#                           'forces': 0.0010976948408342481,
#                           'wood': 0.0010976948408342481,
#                           'april': 0.0010976948408342481,
#                           'production': 0.0010976948408342481,
#                           'reserve': 0.003293084522502744,
#                           'policy': 0.0021953896816684962,
#                           'upgraded': 0.0010976948408342481,
#                           'britain': 0.0010976948408342481,
#                           'owned': 0.0010976948408342481,
#                           'copper': 0.0010976948408342481,
#                           'warship': 0.0010976948408342481,
#                           'plan': 0.0010976948408342481,
#                           'during': 0.0010976948408342481,
#                           'beef': 0.0043907793633369925,
#                           'tenderloin': 0.0010976948408342481,
#                           'striploin': 0.0010976948408342481,
#                           'into': 0.0010976948408342481,
#                           'deficit': 0.0021953896816684962,
#                           'health': 0.0010976948408342481,
#                           'personal': 0.0010976948408342481,
#                           'league': 0.0010976948408342481,
#                           'benchmark': 0.0010976948408342481,
#                           'for': 0.0021953896816684962,
#                           'cent': 0.0010976948408342481,
#                           'superfund': 0.0010976948408342481,
#                           'was': 0.0010976948408342481,
#                           'chamber': 0.0010976948408342481,
#                           'technology': 0.0010976948408342481,
#                           'growth': 0.0010976948408342481,
#                           'farmers': 0.0010976948408342481,
#                           'canada': 0.0010976948408342481,
#                           'canadian': 0.0010976948408342481,
#                           'put': 0.0010976948408342481,
#                           'combining': 0.0010976948408342481,
#                           'housing': 0.0010976948408342481,
#                           'you': 0.0010976948408342481,
#                           'shaw': 0.0010976948408342481,
#                           'failed': 0.0010976948408342481,
#                           'groundnut': 0.0010976948408342481}),
#              ('s',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rift': 0.16666666666666666,
#                           "'": 0.3333333333333333,
#                           'west': 0.3333333333333333,
#                           'trade': 0.16666666666666666}),
#              ('japan',
#               'rift'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mounting': 1.0}),
#              ('rift',
#               'mounting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 1.0}),
#              ('mounting',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'friction': 0.5,
#                           'tension': 0.5}),
#              ('trade',
#               'friction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'between': 0.5,
#                           'with': 0.16666666666666666,
#                           'diplomacy': 0.16666666666666666,
#                           'and': 0.16666666666666666}),
#              ('friction',
#               'between'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'the': 1.0}),
#              ('between',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.10204081632653061,
#                           'start': 0.02040816326530612,
#                           'two': 0.3673469387755102,
#                           'employers': 0.02040816326530612,
#                           'united': 0.08163265306122448,
#                           'demands': 0.02040816326530612,
#                           'countries': 0.02040816326530612,
#                           'ec': 0.02040816326530612,
#                           'dollar': 0.02040816326530612,
#                           'white': 0.02040816326530612,
#                           'prime': 0.061224489795918366,
#                           'report': 0.04081632653061224,
#                           'increased': 0.02040816326530612,
#                           'secured': 0.02040816326530612,
#                           'pork': 0.02040816326530612,
#                           'omani': 0.02040816326530612,
#                           'group': 0.02040816326530612,
#                           'purchase': 0.02040816326530612,
#                           'federal': 0.02040816326530612,
#                           'first': 0.02040816326530612,
#                           'heaviest': 0.02040816326530612,
#                           'growth': 0.02040816326530612}),
#              ('the',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.9582366589327146,
#                           'k': 0.03944315545243619,
#                           'n': 0.002320185614849188}),
#              ('s',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'japan': 0.13636363636363635,
#                           'lead': 0.022727272727272728,
#                           'atlas': 0.022727272727272728,
#                           'new': 0.022727272727272728,
#                           'japanese': 0.06818181818181818,
#                           'rising': 0.022727272727272728,
#                           'britain': 0.045454545454545456,
#                           'europe': 0.045454545454545456,
#                           'west': 0.06818181818181818,
#                           'world': 0.022727272727272728,
#                           'european': 0.022727272727272728,
#                           'the': 0.045454545454545456,
#                           'cain': 0.022727272727272728,
#                           'canada': 0.045454545454545456,
#                           'l': 0.022727272727272728,
#                           'up': 0.022727272727272728,
#                           'hong': 0.022727272727272728,
#                           'u': 0.022727272727272728,
#                           'its': 0.022727272727272728,
#                           'w': 0.09090909090909091,
#                           'other': 0.045454545454545456,
#                           'malaysia': 0.022727272727272728,
#                           'rupert': 0.022727272727272728,
#                           'tight': 0.022727272727272728,
#                           'on': 0.022727272727272728,
#                           'canadian': 0.022727272727272728,
#                           'raise': 0.022727272727272728}),
#              ('and',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'has': 0.047619047619047616,
#                           'might': 0.047619047619047616,
#                           'with': 0.09523809523809523,
#                           "'": 0.09523809523809523,
#                           'harder': 0.047619047619047616,
#                           'look': 0.047619047619047616,
#                           'on': 0.14285714285714285,
#                           'believe': 0.047619047619047616,
#                           'became': 0.047619047619047616,
#                           'which': 0.047619047619047616,
#                           'meanwhile': 0.047619047619047616,
#                           'rather': 0.047619047619047616,
#                           'will': 0.09523809523809523,
#                           'at': 0.047619047619047616,
#                           'to': 0.09523809523809523}),
#              ('japan',
#               'has'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {
): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.0625,
#                           'in': 0.0625,
#                           'less': 0.0625,
#                           'welcomed': 0.0625,
#                           'production': 0.125,
#                           'lead': 0.0625,
#                           'because': 0.0625,
#                           'will': 0.125,
#                           'price': 0.0625,
#                           'low': 0.0625,
#                           'tight': 0.0625,
#                           'higher': 0.0625,
#                           'tougher': 0.0625,
#                           'increase': 0.0625}),
#              ('a',
#               'fall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 0.4,
#                           'of': 0.5,
#                           'from': 0.1}),
#              ('fall',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'malaysian': 0.02857142857142857,
#                           'the': 0.2571428571428571,
#                           'sales': 0.02857142857142857,
#                           'march': 0.02857142857142857,
#                           'key': 0.02857142857142857,
#                           'imports': 0.02857142857142857,
#                           'oil': 0.08571428571428572,
#                           'but': 0.02857142857142857,
#                           'latest': 0.02857142857142857,
#                           'week': 0.02857142857142857,
#                           'major': 0.02857142857142857,
#                           'note': 0.02857142857142857,
#                           'january': 0.05714285714285714,
#                           'exports': 0.02857142857142857,
#                           'february': 0.02857142857142857,
#                           'input': 0.02857142857142857,
#                           'industrial': 0.05714285714285714,
#                           'a': 0.02857142857142857,
#                           'may': 0.08571428571428572,
#                           'unemployment': 0.02857142857142857,
#                           'canadian': 0.02857142857142857}),
#              ('in',
#               'malaysian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'output': 0.5,
#                           'and': 0.5}),
#              ('malaysian',
#               'output'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'hasrul': 1.0}),
#              ('output',
#               'hasrul'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'harahap': 1.0}),
#              ('hasrul',
#               'harahap'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'junior': 1.0}),
#              ('harahap',
#               'junior'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'minister': 1.0}),
#              ('junior',
#               'minister'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'for': 1.0}),
#              ('minister',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tree': 0.5,
#                           'foreign': 0.5}),
#              ('for',
#               'tree'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'crops': 1.0}),
#              ('tree',
#               'crops'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'told': 1.0}),
#              ('crops',
#               'told'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'indonesian': 1.0}),
#              ('told',
#               'indonesian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'reporters': 1.0}),
#              ('prices',
#               'of'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'malaysian': 0.038461538461538464,
#                           'pct': 0.038461538461538464,
#                           'grain': 0.038461538461538464,
#                           'corn': 0.038461538461538464,
#                           'home': 0.038461538461538464,
#                           'cement': 0.038461538461538464,
#                           'the': 0.038461538461538464,
#                           'petrol': 0.15384615384615385,
#                           'cents': 0.038461538461538464,
#                           'gm': 0.038461538461538464,
#                           'coconut': 0.038461538461538464,
#                           'its': 0.038461538461538464,
#                           'aluminum': 0.15384615384615385,
#                           'up': 0.038461538461538464,
#                           'such': 0.038461538461538464,
#                           'to': 0.038461538461538464,
#                           'tungsten': 0.038461538461538464,
#                           'high': 0.038461538461538464,
#                           'sweet': 0.038461538461538464,
#                           'around': 0.038461538461538464}),
#              ('of',
#               'malaysian'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'and': 0.5,
#                           'refined': 0.5}),
#              ('malaysian',
#               'and'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sumatran': 0.3333333333333333,
#                           'japanese': 0.3333333333333333,
#                           'indonesian': 0.3333333333333333}),
#              ('and',
#               'sumatran'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cpo': 1.0}),
#              ('sumatran',
#               'cpo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'are': 1.0}),
#              ('cpo',
#               'are'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'now': 1.0}),
#              ('are',
#               'now'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'around': 0.16666666666666666,
#                           'within': 0.3333333333333333,
#                           'near': 0.16666666666666666,
#                           'paying': 0.16666666666666666,
#                           'being': 0.16666666666666666}),
#              ('now',
#               'around'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dlrs': 1.0}),
#              ('around',
#               'dlrs'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.9285714285714286,
#                           'per': 0.07142857142857142}),
#              ('tonne',
#               'cif'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'for': 1.0}),
#              ('cif',
#               'for'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'delivery': 1.0}),
#              ('for',
#               'delivery'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'in': 0.34615384615384615,
#                           'between': 0.038461538461538464,
#                           'to': 0.11538461538461539,
#                           'may': 0.11538461538461539,
#                           'during': 0.19230769230769232,
#                           'as': 0.038461538461538464,
#                           'at': 0.038461538461538464,
#                           'august': 0.038461538461538464,
#                           'before': 0.038461538461538464,
#                           'of': 0.038461538461538464}),
#              ('delivery',
#               'in'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rotterdam': 0.1,
#                           'the': 0.5,
#                           'including': 0.1,
#                           'gold': 0.1,
#                           'two': 0.1,
#                           'late': 0.1}),
#              ('in',
#               'rotterdam'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'traders': 0.5,
#                           'the': 0.5}),
#              ('rotterdam',
#               'traders'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1.0}),
#              ('harahap',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'indonesia': 0.5,
#                           'it': 0.5}),
#              ('said',
#               'indonesia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'would': 0.2,
#                           'was': 0.2,
#                           "'": 0.4,
#                           'had': 0.2}),
#              ('indonesia',
#               'would'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'maintain': 1.0}),
#              ('would',
#               'maintain'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'its': 1.0}),
#              ('maintain',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'exports': 0.16666666666666666,
#                           'latest': 0.16666666666666666,
#                           'dialogue': 0.16666666666666666,
#                           'current': 0.3333333333333333,
#                           'pct': 0.16666666666666666}),
#              ('its',
#               'exports'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'despite': 1.0}),
#              ('exports',
#               'despite'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'making': 1.0}),
#              ('despite',
#               'making'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'recent': 1.0}),
#              ('making',
#               'recent'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'palm': 1.0}),
#              ('recent',
#               'palm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'oil': 1.0}),
#              ('oil',
#               'purchases'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'from': 1.0}),
#              ('purchases',
#               'from'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'malaysia': 1.0}),
#              ('from',
#               'malaysia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'so': 1.0}),
#              ('malaysia',
#               'so'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'that': 1.0}),
#              ('so',
#               'that'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'it': 0.1111111111111111,
#                           'we': 0.2222222222222222,
#                           'certain': 0.1111111111111111,
#                           'more': 0.1111111111111111,
#                           'abe': 0.2222222222222222,
#                           'in': 0.2222222222222222}),
#              ('that',
#               'it'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'could': 0.012987012987012988,
#                           "'": 0.025974025974025976,
#                           'had': 0.07792207792207792,
#                           'plans': 0.012987012987012988,
#                           'has': 0.12987012987012986,
#                           'was': 0.12987012987012986,
#                           'is': 0.11688311688311688,
#                           'wants': 0.012987012987012988,
#                           'may': 0.025974025974025976,
#                           'should': 0.012987012987012988,
#                           'proposed': 0.012987012987012988,
#                           'continue': 0.012987012987012988,
#                           'did': 0.012987012987012988,
#                           'owns': 0.012987012987012988,
#                           'made': 0.025974025974025976,
#                           'would': 0.16883116883116883,
#                           'wanted': 0.012987012987012988,
#                           'already': 0.012987012987012988,
#                           'will': 0.03896103896103896,
#                           'does': 0.025974025974025976,
#                           'turned': 0.012987012987012988,
#                           'the': 0.012987012987012988,
#                           'and': 0.012987012987012988,
#                           'intends': 0.012987012987012988,
#                           'regards': 0.012987012987012988,
#                           'announced': 0.012987012987012988,
#                           'enjoyed': 0.012987012987012988,
#                           'awarded': 0.012987012987012988}),
#              ('it',
#               'could'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'possibly': 0.06666666666666667,
#                           'open': 0.06666666666666667,
#                           'be': 0.13333333333333333,
#                           'put': 0.06666666666666667,
#                           'sustain': 0.06666666666666667,
#                           'take': 0.13333333333333333,
#                           'realize': 0.06666666666666667,
#                           'also': 0.13333333333333333,
#                           'still': 0.06666666666666667,
#                           'drop': 0.06666666666666667,
#                           'lead': 0.06666666666666667,
#                           'not': 0.06666666666666667}),
#              ('could',
#               'possibly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'increase': 1.0}),
#              ('possibly',
#               'increase'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'its': 1.0}),
#              ('increase',
#               'its'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'international': 0.1111111111111111,
#                           'holding': 0.1111111111111111,
#                           'annual': 0.1111111111111111,
#                           'sales': 0.1111111111111111,
#                           'wheat': 0.1111111111111111,
#                           'dlr': 0.1111111111111111,
#                           'stake': 0.1111111111111111,
#                           'provision': 0.1111111111111111,
#                           'ability': 0.1111111111111111}),
#              ('its',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'market': 0.25,
#                           'oil': 0.25,
#                           'value': 0.25,
#                           'business': 0.25}),
#              ('international',
#               'market'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'share': 0.5,
#                           'because': 0.5}),
#              ('indonesia',
#               'the'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'world': 1.0}),
#              ('s',
#               'second'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'largest': 0.6666666666666666,
#                           'hand': 0.16666666666666666,
#                           'quarter': 0.16666666666666666}),
#              ('second',
#               'largest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'producer': 0.3333333333333333,
#                           'employer': 0.3333333333333333,
#                           'gold': 0.16666666666666666,
#                           'consumers': 0.16666666666666666}),
#              ('largest',
#               'producer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'of': 0.6666666666666666,
#                           'in': 0.3333333333333333}),
#              ...})

# %% [markdown]
# ## **Examples**

# %%
dict(model['japan','has'])
# Out:
# {'raised': 0.058823529411764705,
#  'been': 0.11764705882352941,
#  'the': 0.058823529411764705,
#  'little': 0.11764705882352941,
#  'violated': 0.058823529411764705,
#  'said': 0.17647058823529413,
#  'come': 0.058823529411764705,
#  'no': 0.17647058823529413,
#  'rejected': 0.058823529411764705,
#  'far': 0.058823529411764705,
#  'resulted': 0.058823529411764705}

# %%
dict(model['to','go'])
# Out:
# {'ahead': 0.10526315789473684,
#  'on': 0.10526315789473684,
#  'under': 0.05263157894736842,
#  'against': 0.10526315789473684,
#  'unnoticed': 0.05263157894736842,
#  'into': 0.15789473684210525,
#  'to': 0.05263157894736842,
#  'down': 0.05263157894736842,
#  'through': 0.05263157894736842,
#  'up': 0.05263157894736842,
#  'away': 0.05263157894736842,
#  'for': 0.05263157894736842,
#  'public': 0.10526315789473684}

# %% [markdown]
# ## **Recommending next word**

# %%
max(model['japan','has'], key = lambda w3 : model['japan','has'][w3])
# Out:
# 'said'

# %%
max(model[('to','go')], key = lambda w3 : model['to','go'][w3])
# Out:
# 'into'

# %% [markdown]
# ## **Sample Recommender**

# %%
samp_sentence = input('Enter a sentence to find next word : ')
tokens = samp_sentence.lower().split()
print('Next word : ',max(model[(tokens[-2],tokens[-1])], key = lambda w3 : model[(tokens[-2],tokens[-1])][w3]))
# Out:
# Enter a sentence to find next word : This has to be
# Next word :  acquired
